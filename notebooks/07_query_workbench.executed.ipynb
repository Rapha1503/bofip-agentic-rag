# %% [markdown]
# # Query Workbench
#
# Notebook interactif pour auditer une requete de bout en bout dans le clean-room BOFiP.
#
# Ce notebook montre:
# - la requete brute, sa tokenisation et sa version vectorielle
# - le stage 1 lexical (plusieurs modes)
# - le stage 1 dense documentaire
# - le stage 1 dense documentaire derive des chunks si disponible
# - le stage 1 hybride documentaire
# - les liens/familles BOI des meilleurs documents
# - les meilleurs chunks locaux dans les documents remontes
#
# Ce n'est **pas** un notebook de generation LLM.

# %%
from pathlib import Path
import json
import sys
import numpy as np

PROJECT_ROOT = Path.cwd().resolve().parent
SRC_ROOT = PROJECT_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from bofip_cleanroom.dense_retrieval import DenseDocumentIndex, DenseEncoder, DEFAULT_DENSE_MODEL
from bofip_cleanroom.direct_chunk_retrieval import DirectChunkRetriever, Stage1DocumentHit
from bofip_cleanroom.family_guided_retrieval import FamilyGuidedRetriever, PriorDocumentHit
from bofip_cleanroom.hybrid_retrieval import RankedDoc, reciprocal_rank_fuse
from bofip_cleanroom.jsonio import read_jsonl
from bofip_cleanroom.lexical_retrieval import (
    DocumentLexicalIndex,
    LexicalBM25Index,
    chunk_search_text_body,
    document_search_text_sections_leads,
    get_document_search_text_fn,
    tokenize,
)
from bofip_cleanroom.models import chunk_node_from_dict, raw_document_from_dict
# Out:
# WARNING:tensorflow:From C:\Users\rapha\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# User inputs
QUERY = "Notre startup a le statut JEI et porte des travaux de recherche. Peut-elle recuperer sa creance de CIR tout de suite ?"
CORPUS = "mixed"  # "commentary" or "mixed"
TOP_DOCS = 5
TOP_CHUNKS_PER_DOC = 4
MODEL_NAME = DEFAULT_DENSE_MODEL

# %%
CORPUS_CONFIG = {
    "commentary": {
        "raw_docs": PROJECT_ROOT / "data" / "interim" / "raw_docs_sample_5666.jsonl",
        "chunks": PROJECT_ROOT / "data" / "interim" / "chunks_section_window_sample_5666.jsonl",
        "doc_dense_cache": PROJECT_ROOT / "data" / "interim" / "doc_dense_cache_5666_sections_firstpara_e5.npy",
        "doc_dense_meta": PROJECT_ROOT / "data" / "interim" / "doc_dense_cache_5666_sections_firstpara_e5.json",
        "chunk_dense_cache": PROJECT_ROOT / "data" / "interim" / "chunk_dense_cache_5666_full_e5.npy",
        "label": "Commentaire only (5666 docs)",
    },
    "mixed": {
        "raw_docs": PROJECT_ROOT / "data" / "interim" / "raw_docs_sample_6295.jsonl",
        "chunks": PROJECT_ROOT / "data" / "interim" / "chunks_section_window_sample_6295.jsonl",
        "doc_dense_cache": PROJECT_ROOT / "data" / "interim" / "doc_dense_cache_6295_sections_firstpara_e5.npy",
        "doc_dense_meta": PROJECT_ROOT / "data" / "interim" / "doc_dense_cache_6295_sections_firstpara_e5.json",
        "chunk_dense_cache": None,
        "label": "Full mixed content (6295 docs)",
    },
}

if CORPUS not in CORPUS_CONFIG:
    raise ValueError(f"Unsupported corpus: {CORPUS}")

cfg = CORPUS_CONFIG[CORPUS]
raw_docs = [raw_document_from_dict(item) for item in read_jsonl(cfg["raw_docs"])]
chunks = [chunk_node_from_dict(item) for item in read_jsonl(cfg["chunks"])]
raw_doc_map = {doc.boi_reference: doc for doc in raw_docs}
chunks_by_ref = {}
for chunk in chunks:
    chunks_by_ref.setdefault(chunk.boi_reference, []).append(chunk)

print({"corpus": cfg["label"], "documents": len(raw_docs), "chunks": len(chunks)})
# Out:
# {'corpus': 'Full mixed content (6295 docs)', 'documents': 6295, 'chunks': 68091}

# %% [markdown]
# ## 1. Query normalization and vector

# %%
query_tokens = tokenize(QUERY)
encoder = DenseEncoder(MODEL_NAME)
query_embedding = encoder.encode_queries([QUERY])[0]

{
    "query": QUERY,
    "token_count": len(query_tokens),
    "tokens": query_tokens,
    "embedding_dim": int(query_embedding.shape[0]),
    "embedding_norm": float(np.linalg.norm(query_embedding)),
    "embedding_head": [round(float(x), 6) for x in query_embedding[:16]],
}
# Out:
# {'query': 'Notre startup a le statut JEI et porte des travaux de recherche. Peut-elle recuperer sa creance de CIR tout de suite ?',
#  'token_count': 21,
#  'tokens': ['notre',
#   'startup',
#   'a',
#   'le',
#   'statut',
#   'jei',
#   'et',
#   'porte',
#   'des',
#   'travaux',
#   'de',
#   'recherche.',
#   'peut-elle',
#   'recuperer',
#   'sa',
#   'creance',
#   'de',
#   'cir',
#   'tout',
#   'de',
#   'suite'],
#  'embedding_dim': 768,
#  'embedding_norm': 1.0,
#  'embedding_head': [0.007907,
#   0.051031,
#   0.003516,
#   0.021029,
#   0.014871,
#   -0.037978,
#   -0.008566,
#   -0.046254,
#   0.007047,
#   0.025614,
#   0.001365,
#   -0.001438,
#   0.062959,
#   0.028077,
#   -0.041235,
#   -0.046174]}

# %% [markdown]
# ## 2. Stage 1 lexical document retrieval

# %%
lexical_modes = ["base", "sections", "sections_firstpara", "sections_leads"]
lexical_results = {}
for mode in lexical_modes:
    search_text_fn = document_search_text_sections_leads if mode == "sections_leads" else get_document_search_text_fn(mode)
    index = DocumentLexicalIndex(raw_docs, search_text_fn=search_text_fn)
    hits = index.search_documents(QUERY, top_k=TOP_DOCS)
    lexical_results[mode] = [
        {
            "rank": hit.rank,
            "score": round(hit.score, 4),
            "boi_reference": hit.boi_reference,
            "title": raw_doc_map[hit.boi_reference].title,
            "publication_date": raw_doc_map[hit.boi_reference].publication_date,
        }
        for hit in hits
    ]

lexical_results
# Out:
# {'base': [{'rank': 1,
#    'score': 28.437,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers",
#    'publication_date': '2012-09-12'},
#   {'rank': 2,
#    'score': 27.5554,
#    'boi_reference': 'BOI-LETTRE-000251-20190417',
#    'title': "LETTRE - TCA - Modèle de convention-type à conclure entre le casino et le tiers titulaire de la licence d'entrepreneur de spectacles en cas délégation de tout ou partie de l'organisation de la manifestation",
#    'publication_date': '2019-04-17'},
#   {'rank': 3,
#    'score': 27.3324,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#    'publication_date': '2012-09-12'},
#   {'rank': 4,
#    'score': 26.4354,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'publication_date': '2012-09-12'},
#   {'rank': 5,
#    'score': 25.9725,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-10-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Travaux immobiliers concourant à la construction, à la livraison, à la réparation ou à la réfection des bâtiments de l'Etat, des collectivités locales et des établissements publics autres que ceux à caractère industriel ou commercial assujettis à la TVA",
#    'publication_date': '2012-09-12'}],
#  'sections': [{'rank': 1,
#    'score': 35.7476,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#    'publication_date': '2012-09-12'},
#   {'rank': 2,
#    'score': 35.0866,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-10-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Travaux immobiliers concourant à la construction, à la livraison, à la réparation ou à la réfection des bâtiments de l'Etat, des collectivités locales et des établissements publics autres que ceux à caractère industriel ou commercial assujettis à la TVA",
#    'publication_date': '2012-09-12'},
#   {'rank': 3,
#    'score': 34.5217,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'publication_date': '2012-09-12'},
#   {'rank': 4,
#    'score': 33.3188,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers",
#    'publication_date': '2012-09-12'},
#   {'rank': 5,
#    'score': 32.0072,
#    'boi_reference': 'BOI-ENR-DG-20-40-20230131',
#    'title': "ENR - Dispositions générales - Règles d'exigibilité de l'impôt - Actes exemptés de l'enregistrement",
#    'publication_date': '2023-01-31'}],
#  'sections_firstpara': [{'rank': 1,
#    'score': 42.6481,
#    'boi_reference': 'BOI-SJ-RES-10-20-20-40-20181107',
#    'title': "SJ - Garantie contre les changements de position de l'administration fiscale - Garantie contre les changements de doctrine - Procédures de rescrit fiscal - Garantie apportée par une prise de position formelle sur l'appréciation d'une situation de fait - Rescrits spécifiques avec l'accord implicite en cas d'absence de réponse de l'administration dans un délai encadré - Rescrits relatifs aux jeunes entreprises innovantes (JEI) ou aux jeunes entreprises universitaires (JEU)",
#    'publication_date': '2018-11-07'},
#   {'rank': 2,
#    'score': 41.0083,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt en faveur de la recherche collaborative - Utilisation du crédit d’impôt',
#    'publication_date': '2025-03-26'},
#   {'rank': 3,
#    'score': 39.4783,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#    'publication_date': '2012-09-12'},
#   {'rank': 4,
#    'score': 39.3841,
#    'boi_reference': 'BOI-BIC-PVMV-30-30-50-20120912',
#    'title': 'BIC – Plus-values et moins-values du portefeuille-titres – Cession des titres du portefeuille – Dispositions particulières à la vente en rachat de titres',
#    'publication_date': '2012-09-12'},
#   {'rank': 5,
#    'score': 39.1663,
#    'boi_reference': 'BOI-IF-CFE-10-30-60-20-20250716',
#    'title': 'IF - Cotisation foncière des entreprises - Champ d’application - Personnes et activités exonérées - Autres exonérations facultatives temporaires - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance',
#    'publication_date': '2025-07-16'}],
#  'sections_leads': [{'rank': 1,
#    'score': 42.5416,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux",
#    'publication_date': '2024-07-03'},
#   {'rank': 2,
#    'score': 40.1024,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Obligations déclaratives et contrôle',
#    'publication_date': '2025-08-13'},
#   {'rank': 3,
#    'score': 39.8524,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'publication_date': '2012-09-12'},
#   {'rank': 4,
#    'score': 39.8261,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#    'publication_date': '2012-09-12'},
#   {'rank': 5,
#    'score': 39.627,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt en faveur de la recherche collaborative - Utilisation du crédit d’impôt',
#    'publication_date': '2025-03-26'}]}

# %% [markdown]
# ## 3. Stage 1 dense document retrieval

# %%
dense_embeddings = np.load(cfg["doc_dense_cache"])
dense_index = DenseDocumentIndex(raw_docs, dense_embeddings)
dense_hits = dense_index.search_from_vector(query_embedding, top_k=TOP_DOCS)
dense_results = [
    {
        "rank": hit.rank,
        "score": round(hit.score, 6),
        "boi_reference": hit.boi_reference,
        "title": hit.document.title,
        "publication_date": hit.document.publication_date,
    }
    for hit in dense_hits
]
dense_results
# Out:
# [{'rank': 1,
#   'score': 0.864633,
#   'boi_reference': 'BOI-RES-SJ-000014-20210309',
#   'title': "RES - Sécurité juridique - Garantie contre les changements de position de l'administration fiscale - Délai de dépôt d'une demande de rescrit relatif aux jeunes entreprises innovantes (JEI) - (LPF, art. L 80 B, 4°)",
#   'publication_date': '2021-03-09'},
#  {'rank': 2,
#   'score': 0.864615,
#   'boi_reference': 'BOI-RES-BIC-000034-20210713',
#   'title': "RES - Bénéfices industriels et commerciaux - Réductions et crédits d'impôt - Crédit d'impôt recherche - Eligibilité des PME au sens du droit de l'Union européenne au remboursement immédiat des créances de crédit d'impôt recherche",
#   'publication_date': '2021-07-13'},
#  {'rank': 3,
#   'score': 0.862922,
#   'boi_reference': 'BOI-RES-BIC-000172-20241211',
#   'title': 'RES - Bénéfices industriels et commerciaux - Champ d’application et territorialité - Participations au capital des jeunes entreprises innovantes détenues par des fondations de coopération scientifique',
#   'publication_date': '2024-12-11'},
#  {'rank': 4,
#   'score': 0.855487,
#   'boi_reference': 'BOI-RES-BIC-000017-20250813',
#   'title': 'RES - Bénéfices industriels et commerciaux - Réductions et crédits d’impôt - Crédit d’impôt recherche (CIR) - Dépenses de personnel éligibles - Notion de premier recrutement d’un jeune docteur',
#   'publication_date': '2025-08-13'},
#  {'rank': 5,
#   'score': 0.854788,
#   'boi_reference': 'BOI-ANNX-000021-20140627',
#   'title': "ANNEXE - IR - Crédit d'impôt en faveur du développement durable (CGI, art. 200 quater) - Exemple d'installation d'un système de récupération et de traitement des eaux pluviales",
#   'publication_date': '2014-06-27'}]

# %% [markdown]
# ## 3b. Stage 1 chunk-dense document retrieval

# %%
chunk_dense_results = []
if cfg["chunk_dense_cache"] and cfg["chunk_dense_cache"].exists():
    from bofip_cleanroom.dense_retrieval import DenseIndex

    chunk_dense_embeddings = np.load(cfg["chunk_dense_cache"])
    chunk_dense_index = DenseIndex(chunks, chunk_dense_embeddings)
    chunk_dense_hits = chunk_dense_index.search_documents_from_vector(query_embedding, top_k=TOP_DOCS)
    chunk_dense_results = [
        {
            "rank": hit.rank,
            "score": round(hit.score, 6),
            "boi_reference": hit.boi_reference,
            "title": raw_doc_map[hit.boi_reference].title,
            "best_chunk_id": hit.best_chunk.chunk_id,
            "best_chunk_section": " > ".join(hit.best_chunk.section_path),
        }
        for hit in chunk_dense_hits
    ]
else:
    chunk_dense_results = [{"info": "chunk-dense cache not available for this corpus"}]
chunk_dense_results
# Out:
# [{'info': 'chunk-dense cache not available for this corpus'}]

# %% [markdown]
# ## 4. Stage 1 hybrid document retrieval

# %%
hybrid_hits_simple = reciprocal_rank_fuse(
    {
        "lexical": [
            RankedDoc(
                boi_reference=row["boi_reference"],
                score=float(row["score"]),
                rank=row["rank"],
                source="lexical",
            )
            for row in lexical_results["sections"]
        ],
        "dense": [
            RankedDoc(
                boi_reference=row["boi_reference"],
                score=float(row["score"]),
                rank=row["rank"],
                source="dense",
            )
            for row in dense_results
        ],
    },
    top_k=TOP_DOCS,
    rank_constant=60,
    source_weights={"lexical": 1.0, "dense": 1.0},
)
hybrid_results_simple = [
    {
        "rank": hit.rank,
        "score": round(hit.score, 6),
        "boi_reference": hit.boi_reference,
        "sources": hit.sources,
        "ranks": hit.ranks,
        "title": raw_doc_map[hit.boi_reference].title,
    }
    for hit in hybrid_hits_simple
]

hybrid_hits_promoted = reciprocal_rank_fuse(
    {
        "base": [
            RankedDoc(
                boi_reference=row["boi_reference"],
                score=float(row["score"]),
                rank=row["rank"],
                source="base",
            )
            for row in lexical_results["base"]
        ],
        "sections_leads": [
            RankedDoc(
                boi_reference=row["boi_reference"],
                score=float(row["score"]),
                rank=row["rank"],
                source="sections_leads",
            )
            for row in lexical_results["sections_leads"]
        ],
        "dense": [
            RankedDoc(
                boi_reference=row["boi_reference"],
                score=float(row["score"]),
                rank=row["rank"],
                source="dense",
            )
            for row in dense_results
        ],
        **(
            {
                "chunk_dense": [
                    RankedDoc(
                        boi_reference=row["boi_reference"],
                        score=float(row["score"]),
                        rank=row["rank"],
                        source="chunk_dense",
                    )
                    for row in chunk_dense_results
                    if "boi_reference" in row
                ]
            }
            if chunk_dense_results and "boi_reference" in chunk_dense_results[0]
            else {}
        ),
    },
    top_k=TOP_DOCS,
    rank_constant=60,
    source_weights=(
        {"base": 1.0, "sections_leads": 2.0, "dense": 1.0, "chunk_dense": 2.0}
        if chunk_dense_results and "boi_reference" in chunk_dense_results[0]
        else {"base": 1.0, "sections_leads": 2.0, "dense": 1.0}
    ),
)
hybrid_results_promoted = [
    {
        "rank": hit.rank,
        "score": round(hit.score, 6),
        "boi_reference": hit.boi_reference,
        "sources": hit.sources,
        "ranks": hit.ranks,
        "title": raw_doc_map[hit.boi_reference].title,
    }
    for hit in hybrid_hits_promoted
]

{
    "simple_sections_plus_dense": hybrid_results_simple,
    "promoted_current_pipeline": hybrid_results_promoted,
}
# Out:
# {'simple_sections_plus_dense': [{'rank': 1,
#    'score': 0.016393,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'sources': ['lexical'],
#    'ranks': {'lexical': 1},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option"},
#   {'rank': 2,
#    'score': 0.016393,
#    'boi_reference': 'BOI-RES-SJ-000014-20210309',
#    'sources': ['dense'],
#    'ranks': {'dense': 1},
#    'title': "RES - Sécurité juridique - Garantie contre les changements de position de l'administration fiscale - Délai de dépôt d'une demande de rescrit relatif aux jeunes entreprises innovantes (JEI) - (LPF, art. L 80 B, 4°)"},
#   {'rank': 3,
#    'score': 0.016129,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-10-20120912',
#    'sources': ['lexical'],
#    'ranks': {'lexical': 2},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Travaux immobiliers concourant à la construction, à la livraison, à la réparation ou à la réfection des bâtiments de l'Etat, des collectivités locales et des établissements publics autres que ceux à caractère industriel ou commercial assujettis à la TVA"},
#   {'rank': 4,
#    'score': 0.016129,
#    'boi_reference': 'BOI-RES-BIC-000034-20210713',
#    'sources': ['dense'],
#    'ranks': {'dense': 2},
#    'title': "RES - Bénéfices industriels et commerciaux - Réductions et crédits d'impôt - Crédit d'impôt recherche - Eligibilité des PME au sens du droit de l'Union européenne au remboursement immédiat des créances de crédit d'impôt recherche"},
#   {'rank': 5,
#    'score': 0.015873,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'sources': ['lexical'],
#    'ranks': {'lexical': 3},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie"}],
#  'promoted_current_pipeline': [{'rank': 1,
#    'score': 0.047371,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'sources': ['base', 'sections_leads'],
#    'ranks': {'base': 4, 'sections_leads': 3},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie"},
#   {'rank': 2,
#    'score': 0.047123,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'sources': ['base', 'sections_leads'],
#    'ranks': {'base': 3, 'sections_leads': 4},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option"},
#   {'rank': 3,
#    'score': 0.032787,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'sources': ['sections_leads'],
#    'ranks': {'sections_leads': 1},
#    'title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux"},
#   {'rank': 4,
#    'score': 0.032258,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'sources': ['sections_leads'],
#    'ranks': {'sections_leads': 2},
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Obligations déclaratives et contrôle'},
#   {'rank': 5,
#    'score': 0.030769,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'sources': ['sections_leads'],
#    'ranks': {'sections_leads': 5},
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt en faveur de la recherche collaborative - Utilisation du crédit d’impôt'}]}

# %% [markdown]
# ## 5. Promoted stage 2: direct local chunk retrieval
#
# Baseline passage promue actuelle:
# - stage 1 documentaire multiview hybride
# - puis recherche locale de chunks dans les top docs stage 1
# - `chunk_mode = full`
#
# Le family-guided reste plus bas comme variante experimentale.

# %%
direct_retriever = DirectChunkRetriever(chunks, local_chunk_mode="full")
direct_stage2 = direct_retriever.search(
    QUERY,
    lexical_query=QUERY,
    stage1_hits=[
        Stage1DocumentHit(
            rank=row["rank"],
            score=float(row["score"]),
            boi_reference=row["boi_reference"],
        )
        for row in hybrid_results_promoted
    ],
    top_docs=5,
    chunks_per_doc=3,
    max_chunks=8,
)

{
    "document_hits": hybrid_results_promoted,
    "direct_chunk_hits": [
        {
            "global_rank": hit.global_rank,
            "boi_reference": hit.boi_reference,
            "document_rank": hit.document_rank,
            "local_rank": hit.local_rank,
            "local_score": round(hit.local_score, 4),
            "section_path": " > ".join(hit.chunk.section_path),
            "chunk_id": hit.chunk.chunk_id,
            "chunk_kind": hit.chunk.chunk_kind,
            "text": hit.chunk.text[:800],
        }
        for hit in direct_stage2.chunk_hits
    ],
}
# Out:
# {'document_hits': [{'rank': 1,
#    'score': 0.047371,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'sources': ['base', 'sections_leads'],
#    'ranks': {'base': 4, 'sections_leads': 3},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie"},
#   {'rank': 2,
#    'score': 0.047123,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'sources': ['base', 'sections_leads'],
#    'ranks': {'base': 3, 'sections_leads': 4},
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option"},
#   {'rank': 3,
#    'score': 0.032787,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'sources': ['sections_leads'],
#    'ranks': {'sections_leads': 1},
#    'title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux"},
#   {'rank': 4,
#    'score': 0.032258,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'sources': ['sections_leads'],
#    'ranks': {'sections_leads': 2},
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Obligations déclaratives et contrôle'},
#   {'rank': 5,
#    'score': 0.030769,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'sources': ['sections_leads'],
#    'ranks': {'sections_leads': 5},
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt en faveur de la recherche collaborative - Utilisation du crédit d’impôt'}],
#  'direct_chunk_hits': [{'global_rank': 1,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'document_rank': 1,
#    'local_rank': 1,
#    'local_score': 11.3092,
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00000__1472-pgp-paragraph-00006__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers-cas-des-immeubles-affect-s-l-habitation-pour-les-trois-quarts-au-moins-de-leur-superficie',
#    'chunk_kind': 'paragraph_window',
#    'text': "En application des dispositions de l' article 78-3, al. 2 et 3 de l'annexe III au code général des impôts (CGI) , l'option ne s'applique pas aux travaux qui entrent dans le cadre des opérations concourant : - à la production ou à la livraison des immeubles dont les trois-quarts au moins de la superficie totale sont affectés à l'habitation ; - à la réparation et à la réfection des locaux d'habitation ainsi que de parties communes des immeubles dont les trois-quarts au moins de leur superficie sont affectés à l'habitation. Il sera tout d'abord procédé à la définition de la notion d'immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie pour ensuite préciser les travaux immobiliers concernés qui comprennent : - les travaux d'aménagement des terrains destinés à rec"},
#   {'global_rank': 2,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'document_rank': 2,
#    'local_rank': 1,
#    'local_score': 9.9053,
#    'section_path': "III. Précisions complémentaires > F. Travaux de construction d'un centre médico-pédagogique et professionnel",
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00044__1473-pgp-paragraph-00045__iii-pr-cisions-compl-mentaires-f-travaux-de-construction-d-un-centre-m-dico-p-dagogique-et-professionnel',
#    'chunk_kind': 'paragraph_window',
#    'text': "Les travaux de construction d'un tel édifice n'ouvrent pas droit à l'option pour le paiement de la TVA lors de la livraison, à condition que cet immeuble soit affecté à l'habitation pour les trois quarts au moins de sa superficie. À cet égard, compte tenu de la nature de l'enseignement et des soins prodigués dans les centres médico-pédagogiques et professionnels, les locaux où séjournent les inadaptés mentaux placés sous le régime de l'externat sont considérés comme affectés à l'habitation, dès l'instant où les centres ne sont pas destinés à une exploitation de caractère industriel ou commercial."},
#   {'global_rank': 3,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'document_rank': 3,
#    'local_rank': 1,
#    'local_score': 14.1606,
#    'section_path': "I. Nature des avantages > B. Articulation avec le bénéfice du crédit d'impôt pour dépenses de recherche (CIR) et du crédit d'impôt en faveur de la recherche collaborative (CICo)",
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00013__5357-pgp-paragraph-00014__i-nature-des-avantages-b-articulation-avec-le-b-n-fice-du-cr-dit-d-imp-t-pour-d-penses-de-recherche-cir-et-du-cr-dit-d-imp-t-en-faveur-de-la-recherche-collaborative-cico',
#    'chunk_kind': 'paragraph_window',
#    'text': "Le I de l' article 244 quater B du CGI et le I de l' article 244 quater B bis du CGI prévoient expressément que les entreprises exonérées d'impôt sur les bénéfices en application de l' article 44 sexies A du CGI peuvent également solliciter le bénéfice du CIR et du CICo. De plus, le 3° du II de l' article 199 ter B du CGI et le 3° du II de l' article 199 ter B bis du CGI prévoient la possibilité pour les JEI mentionnées à l' article 44 sexies-0 A du CGI de demander le remboursement immédiat du CIR et du CICo. Ainsi, les JEI, quelle que soit leur année de création, peuvent bénéficier du remboursement immédiat de leur créance de CIR ou de CICo constatée au titre d'une année au cours de laquelle elles bénéficient de la qualification de JEI."},
#   {'global_rank': 4,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'document_rank': 4,
#    'local_rank': 1,
#    'local_score': 11.8118,
#    'section_path': 'I. Souscription d’une déclaration spéciale conforme à un modèle établi par l’administration > B. Cas particuliers > 1. Pièces justificatives à produire par les entreprises créées depuis moins de deux ans > b. Pièces à produire',
#    'chunk_id': '4673-PGP__section_window__4673-pgp-paragraph-00027__4673-pgp-paragraph-00030__i-souscription-d-une-d-claration-sp-ciale-conforme-un-mod-le-tabli-par-l-administration-b-cas-particuliers-1-pi-ces-justificatives-produire-par-les-entreprises-cr-es-depuis-moins-de-deux-ans-b-pi-ces-produire',
#    'chunk_kind': 'paragraph_window',
#    'text': 'Les entreprises créées depuis moins de deux ans doivent présenter spontanément à l’appui de leur demande de remboursement immédiat de créance de CIR des pièces permettant d’établir la réalité de l’activité de recherche qu’elles exercent. Elles peuvent ainsi joindre, à leur demande de remboursement immédiat de créance de CIR, des documents tels que contrats, factures, déclaration DADS-U ou DSN et feuilles de paie délivrées aux chercheurs et techniciens ou tout autre moyen de preuve. Il n’est, toutefois, pas exigé que l’entreprise produise l’ensemble des justificatifs relatifs aux différentes catégories de dépenses éligibles au crédit d’impôt. En revanche, lors des demandes de restitution de crédit d’impôt ayant le caractère de réclamation contentieuse l’administration des finances publiques'},
#   {'global_rank': 5,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'document_rank': 5,
#    'local_rank': 1,
#    'local_score': 6.9779,
#    'section_path': 'II. Nature, comptabilisation et utilisation de la créance de crédit d’impôt non imputé (solde excédentaire) > B. Utilisation de la créance > 2. Cas particuliers du remboursement immédiat de la créance pour certaines entreprises > a. Entreprises nouvelles',
#    'chunk_id': '13773-PGP__section_window__13773-pgp-paragraph-00033__13773-pgp-paragraph-00033__ii-nature-comptabilisation-et-utilisation-de-la-cr-ance-de-cr-dit-d-imp-t-non-imput-solde-exc-dentaire-b-utilisation-de-la-cr-ance-2-cas-particuliers-du-remboursement-imm-diat-de-la-cr-ance-pour-certaines-entreprises-a-entreprises-nouvelles',
#    'chunk_kind': 'paragraph',
#    'text': 'Remarque : Cette condition de détention de capital doit être respectée tout au long des années au cours desquelles les dépenses ouvrant droit au crédit d’impôt dont le remboursement est demandé ont été exposées.'},
#   {'global_rank': 6,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'document_rank': 1,
#    'local_rank': 2,
#    'local_score': 9.229,
#    'section_path': "IV. Travaux d'installation d'équipements fonctionnels > B. Précisions complémentaires > 2. Installation d'armoires sèche-linge",
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00096__1472-pgp-paragraph-00097__iv-travaux-d-installation-d-quipements-fonctionnels-b-pr-cisions-compl-mentaires-2-installation-d-armoires-s-che-linge',
#    'chunk_kind': 'paragraph_window',
#    'text': "Le régime des travaux immobiliers s'applique aux installations d'armoires sèche-linge dans la mesure où elles font corps avec la maçonnerie de l'immeuble et perdent leur caractère mobilier par suite de leur incorporation aux locaux d'habitation. En revanche, lorsque les armoires sèche-linge se présentent sous la forme de meubles simplement raccordés au secteur électrique, à la distribution d'eau froide, à la colonne d'évacuation des eaux et que leur déplacement n'entraîne pas de graves détériorations soit des armoires elles-mêmes, soit de l'immeuble dans lequel elles ont disposées, de telles installations ne peuvent bénéficier du régime des travaux immobiliers, mais s'analysent en des ventes de matériels assorties de prestations de services."},
#   {'global_rank': 7,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'document_rank': 2,
#    'local_rank': 2,
#    'local_score': 9.7538,
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00000__1473-pgp-paragraph-00003__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers-autres-cas-d-exclusion-de-l-option',
#    'chunk_kind': 'paragraph_window',
#    'text': "Les développements qui suivent, sont relatifs aux deux cas d'exclusion prévus par l' article 78-3-a-4° et b de l'annexe III au code général des impôts (CGI) concernant les travaux immobiliers : - réalisés sur les immeubles affectés à l'exercice public du culte et les locaux nécessaires à cette activité ; - effectués par les redevables inscrits au répertoire des métiers placés sur option sous le régime du réel simplifié d'imposition. Sont ensuite exposées des précisions pour certaines catégories de travaux immobiliers portant sur des immeubles spécifiques."},
#   {'global_rank': 8,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'document_rank': 3,
#    'local_rank': 2,
#    'local_score': 10.5857,
#    'section_path': "III. Combinaison du dispositif avec d'autres régimes d'exonération",
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00078__5357-pgp-paragraph-00082__iii-combinaison-du-dispositif-avec-d-autres-r-gimes-d-exon-ration',
#    'chunk_kind': 'paragraph_window',
#    'text': 'Il est précisé que les entreprises qui entendent bénéficier des exonérations d’impôts directs locaux attachées à ce statut de JEI, qu’il s’agisse de la taxe professionnelle (CGI, art. 1466 D), remplacée par la contribution économique territoriale à compter du 1 er janvier 2010, ou de la taxe foncière sur les propriétés bâties (CGI, art. 1383 D), doivent, dans la plupart des cas, en faire la demande sur papier libre. Concernant le second point, l’option est irrévocable. Toutefois, lorsqu’une entreprise répondant aux seules conditions d’éligibilité au statut de JEI a formulé auprès du service des impôts compétent, à tort, une option pour l’application d’un autre régime de faveur, elle peut demander le bénéfice du régime d’exonération prévu en faveur des JEI dans le cadre d’une réclamation co'}]}

# %% [markdown]
# ## 6. Family / related documents for the top hybrid hits

# %%
def ref_core(ref):
    parts = ref.split("-")
    if parts and parts[-1].isdigit() and len(parts[-1]) == 8:
        parts = parts[:-1]
    return parts

def parent_refs(ref):
    core = ref_core(ref)
    parents = []
    for cut in range(len(core) - 1, 1, -1):
        candidate = "-".join(core[:cut])
        for doc in raw_docs:
            other = ref_core(doc.boi_reference)
            if other == core[:cut]:
                parents.append(doc.boi_reference)
    return sorted(set(parents))

def child_refs(ref, limit=8):
    core = ref_core(ref)
    children = []
    for doc in raw_docs:
        other = ref_core(doc.boi_reference)
        if len(other) > len(core) and other[:len(core)] == core:
            children.append(doc.boi_reference)
    return sorted(children)[:limit]

family_rows = []
for row in hybrid_results_promoted[:3]:
    doc = raw_doc_map[row["boi_reference"]]
    family_rows.append(
        {
            "boi_reference": row["boi_reference"],
            "title": doc.title,
            "xml_relations": [rel.value for rel in doc.relations[:8]],
            "parents": parent_refs(row["boi_reference"])[:5],
            "children": child_refs(row["boi_reference"], limit=8),
        }
    )

family_rows
# Out:
# [{'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#   'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#   'xml_relations': ['Contenu:325-PGP'],
#   'parents': ['BOI-TVA-20230621',
#    'BOI-TVA-BASE-20-20190807',
#    'BOI-TVA-BASE-20-50-20-20120912',
#    'BOI-TVA-BASE-20-50-20120912',
#    'BOI-TVA-BASE-20140127'],
#   'children': []},
#  {'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#   'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#   'xml_relations': ['Contenu:325-PGP'],
#   'parents': ['BOI-TVA-20230621',
#    'BOI-TVA-BASE-20-20190807',
#    'BOI-TVA-BASE-20-50-20-20120912',
#    'BOI-TVA-BASE-20-50-20120912',
#    'BOI-TVA-BASE-20140127'],
#   'children': []},
#  {'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#   'title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux",
#   'xml_relations': ['Actualite:14329-PGP', 'Contenu:5356-PGP'],
#   'parents': ['BOI-BIC-20160706',
#    'BOI-BIC-CHAMP-20200205',
#    'BOI-BIC-CHAMP-80-20-20-20200304',
#    'BOI-BIC-CHAMP-80-20-20200304',
#    'BOI-BIC-CHAMP-80-20130325'],
#   'children': []}]

# %% [markdown]
# ## 7. Experimental family-guided variant
#
# Variante utile pour diagnostiquer les voisinages documentaires BOFiP.
# Elle n'est plus la baseline promue pour retrouver le bon passage.

# %%
family_retriever = FamilyGuidedRetriever(
    raw_docs,
    chunks,
    family_doc_mode="sections_leads",
    family_doc_stem=True,
    local_chunk_mode="body",
)
family_guided = family_retriever.search(
    QUERY,
    lexical_query=QUERY,
    stage1_hits=[
        PriorDocumentHit(
            rank=row["rank"],
            score=float(row["score"]),
            boi_reference=row["boi_reference"],
        )
        for row in hybrid_results_promoted
    ],
    family_top_docs=2,
    top_docs=5,
    chunks_per_doc=2,
    max_chunks=8,
    tail_weight=0.25,
    preserve_stage1_top1=True,
)

{
    "family_anchor_bois": family_guided.family_selection.anchor_references,
    "family_prefixes": [list(prefix) for prefix in family_guided.family_selection.prefixes],
    "family_members_count": len(family_guided.family_selection.members),
    "family_document_hits": [
        {
            "rank": hit.rank,
            "boi_reference": hit.boi_reference,
            "combined_score": round(hit.combined_score, 6),
            "family_rank": hit.family_rank,
            "prior_rank": hit.prior_rank,
            "tail_rank": hit.tail_rank,
            "tail_score": round(hit.tail_score, 6) if hit.tail_score is not None else None,
            "title": hit.title,
        }
        for hit in family_guided.document_hits
    ],
    "family_chunk_hits": [
        {
            "global_rank": hit.global_rank,
            "document_rank": hit.document_rank,
            "local_rank": hit.local_rank,
            "boi_reference": hit.boi_reference,
            "section_path": " > ".join(hit.chunk.section_path),
            "chunk_id": hit.chunk.chunk_id,
            "text": hit.chunk.text[:800],
        }
        for hit in family_guided.chunk_hits
    ],
}
# Out:
# {'family_anchor_bois': ['BOI-TVA-BASE-20-50-20-20-20120912',
#   'BOI-TVA-BASE-20-50-20-30-20120912'],
#  'family_prefixes': [['BOI', 'TVA', 'BASE', '20', '50', '20'],
#   ['BOI', 'TVA', 'BASE', '20', '50', '20']],
#  'family_members_count': 4,
#  'family_document_hits': [{'rank': 1,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'combined_score': 1.06994,
#    'family_rank': 1,
#    'prior_rank': 1,
#    'tail_rank': 4,
#    'tail_score': -0.034427,
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie"},
#   {'rank': 2,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'combined_score': 0.747237,
#    'family_rank': 2,
#    'prior_rank': 2,
#    'tail_rank': 3,
#    'tail_score': -0.031242,
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option"},
#   {'rank': 3,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20120912',
#    'combined_score': 0.303571,
#    'family_rank': 4,
#    'prior_rank': None,
#    'tail_rank': 1,
#    'tail_score': 0.879188,
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers"},
#   {'rank': 4,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-10-20120912',
#    'combined_score': 0.239717,
#    'family_rank': 3,
#    'prior_rank': None,
#    'tail_rank': 2,
#    'tail_score': 0.633398,
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Travaux immobiliers concourant à la construction, à la livraison, à la réparation ou à la réfection des bâtiments de l'Etat, des collectivités locales et des établissements publics autres que ceux à caractère industriel ou commercial assujettis à la TVA"}],
#  'family_chunk_hits': [{'global_rank': 1,
#    'document_rank': 1,
#    'local_rank': 1,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'section_path': "IV. Travaux d'installation d'équipements fonctionnels > B. Précisions complémentaires > 2. Installation d'armoires sèche-linge",
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00096__1472-pgp-paragraph-00097__iv-travaux-d-installation-d-quipements-fonctionnels-b-pr-cisions-compl-mentaires-2-installation-d-armoires-s-che-linge',
#    'text': "Le régime des travaux immobiliers s'applique aux installations d'armoires sèche-linge dans la mesure où elles font corps avec la maçonnerie de l'immeuble et perdent leur caractère mobilier par suite de leur incorporation aux locaux d'habitation. En revanche, lorsque les armoires sèche-linge se présentent sous la forme de meubles simplement raccordés au secteur électrique, à la distribution d'eau froide, à la colonne d'évacuation des eaux et que leur déplacement n'entraîne pas de graves détériorations soit des armoires elles-mêmes, soit de l'immeuble dans lequel elles ont disposées, de telles installations ne peuvent bénéficier du régime des travaux immobiliers, mais s'analysent en des ventes de matériels assorties de prestations de services."},
#   {'global_rank': 2,
#    'document_rank': 1,
#    'local_rank': 2,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00000__1472-pgp-paragraph-00006__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers-cas-des-immeubles-affect-s-l-habitation-pour-les-trois-quarts-au-moins-de-leur-superficie',
#    'text': "En application des dispositions de l' article 78-3, al. 2 et 3 de l'annexe III au code général des impôts (CGI) , l'option ne s'applique pas aux travaux qui entrent dans le cadre des opérations concourant : - à la production ou à la livraison des immeubles dont les trois-quarts au moins de la superficie totale sont affectés à l'habitation ; - à la réparation et à la réfection des locaux d'habitation ainsi que de parties communes des immeubles dont les trois-quarts au moins de leur superficie sont affectés à l'habitation. Il sera tout d'abord procédé à la définition de la notion d'immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie pour ensuite préciser les travaux immobiliers concernés qui comprennent : - les travaux d'aménagement des terrains destinés à rec"},
#   {'global_rank': 3,
#    'document_rank': 2,
#    'local_rank': 1,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'section_path': "III. Précisions complémentaires > F. Travaux de construction d'un centre médico-pédagogique et professionnel",
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00044__1473-pgp-paragraph-00045__iii-pr-cisions-compl-mentaires-f-travaux-de-construction-d-un-centre-m-dico-p-dagogique-et-professionnel',
#    'text': "Les travaux de construction d'un tel édifice n'ouvrent pas droit à l'option pour le paiement de la TVA lors de la livraison, à condition que cet immeuble soit affecté à l'habitation pour les trois quarts au moins de sa superficie. À cet égard, compte tenu de la nature de l'enseignement et des soins prodigués dans les centres médico-pédagogiques et professionnels, les locaux où séjournent les inadaptés mentaux placés sous le régime de l'externat sont considérés comme affectés à l'habitation, dès l'instant où les centres ne sont pas destinés à une exploitation de caractère industriel ou commercial."},
#   {'global_rank': 4,
#    'document_rank': 2,
#    'local_rank': 2,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'section_path': "III. Précisions complémentaires > B. Travaux d'études et de reconnaissance des sols > 1. Nature et régime des opérations réalisées dans le cadre d'un marché global > b. Régime fiscal applicable",
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00020__1473-pgp-paragraph-00027__iii-pr-cisions-compl-mentaires-b-travaux-d-tudes-et-de-reconnaissance-des-sols-1-nature-et-r-gime-des-op-rations-r-alis-es-dans-le-cadre-d-un-march-global-b-r-gime-fiscal-applicable',
#    'text': "- travaux d'entreprise et travaux d'interprétation réalisés dans le cadre d'un marché global en vue de la recherche et de l'exploitation des eaux souterraines, des produits pétroliers et des substances minières ; L'ensemble des sondages, forages et des travaux d'interprétation préliminaires à l'exploitation de gisements, nappes, filons, sources, etc., s'analysent en des prestations de services. En revanche, bénéficient du régime des travaux immobiliers, les constructions, aménagements et travaux de nature immobilière entrepris en vue de déterminer l'importance des gisements ou nappes découverts, d'assurer l'extraction des minerais et autres produits, le captage des sources, le stockage du gaz dans les cavités souterraines, etc. - travaux d'entreprise et d'interprétation réalisés dans le ca"},
#   {'global_rank': 5,
#    'document_rank': 3,
#    'local_rank': 1,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20120912',
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers",
#    'chunk_id': '1466-PGP__section_window__1466-pgp-paragraph-00000__1466-pgp-paragraph-00005__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers',
#    'text': "En application de l' article 269-2-c du code général des impôts (CGI) , les entrepreneurs de travaux immobiliers peuvent opter pour le paiement de la TVA sur les livraisons de travaux immobiliers (section 1, cf. BOI-TVA-BASE-20-50-10 ). Cependant, l' article 78-3-a et b de l'annexe III au CGI énumère les travaux exclus de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers. La présente section est consacrée : - aux travaux immobiliers concourant à la construction, à la livraison, à la réparation ou à la réfection des bâtiments de l'Etat, des collectivités locales et des établissements publics autres que ceux à caractère industriel ou commercial assujettis à la TVA (sous-section 1, cf. BOI-TVA-BASE-20-50-20-10 ) ; - aux travaux immobiliers concourant à la construct"},
#   {'global_rank': 6,
#    'document_rank': 3,
#    'local_rank': 2,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20120912',
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers",
#    'chunk_id': '1466-PGP__section_window__1466-pgp-paragraph-00006__1466-pgp-paragraph-00006__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers',
#    'text': "Ces travaux immobiliers donnent lieu au paiement de la taxe au moment de l'encaissement des acomptes ou du montant des mémoires ou factures ( CGI, art. 269 )."},
#   {'global_rank': 7,
#    'document_rank': 4,
#    'local_rank': 1,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-10-20120912',
#    'section_path': 'I. Première condition relative à la qualité de bénéficiaire des travaux > B. Classification des établissements publics > 2. Les établissements publics à caractère industriel ou commercial',
#    'chunk_id': '1447-PGP__section_window__1447-pgp-paragraph-00028__1447-pgp-paragraph-00039__i-premi-re-condition-relative-la-qualit-de-b-n-ficiaire-des-travaux-b-classification-des-tablissements-publics-2-les-tablissements-publics-caract-re-industriel-ou-commercial',
#    'text': "Ces établissements, créés en vue de permettre une gestion lucrative d'un service public, sont soumis aux règles du droit privé. Ils comprennent principalement des établissements publics nationaux : - organismes présentant un caractère d'intérêt national : Commissariat à l'énergie atomique et aux énergies alternatives, Centre national d'études spatiales, Office national des forêts, Caisse nationale des marchés de l'Etat, Fonds d'orientation et de régularisation des marchés agricoles, institut français de recherche pour l'exploitation de la mer (IFREMER) ; - organismes assurant le fonctionnement d'entreprises publiques : Electricité de France et Gaz de France, Caisse nationale de l'énergie ; - organismes assurant des activités d'ordre économique : Office national interprofessionnel des céréa"},
#   {'global_rank': 8,
#    'document_rank': 4,
#    'local_rank': 2,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-10-20120912',
#    'section_path': 'II. Deuxième condition relative à la nature des travaux immobiliers > A. Travaux immobiliers relatifs aux voies > 3. Voirie par eau',
#    'chunk_id': '1447-PGP__section_window__1447-pgp-paragraph-00069__1447-pgp-paragraph-00074__ii-deuxi-me-condition-relative-la-nature-des-travaux-immobiliers-a-travaux-immobiliers-relatifs-aux-voies-3-voirie-par-eau',
#    'text': "La voirie par eau est constituée par l'ensemble des voies de communication utilisées par la navigation pour le transport des personnes et des marchandises. Elle comprend : - les cours d'eau navigables et flottables ; - les canaux de navigation qui se divisent en canaux proprement dits et en rivières canalisées ; - les parties du domaine public maritime affectées à la navigation. D'une manière générale, les travaux immobiliers exécutés à la charge de l'État ou des collectivités locales pour l'emménagement, la réparation ou la réfection de ces voies ne bénéficient pas de l'option. Il en est alors ainsi notamment des travaux de construction, de réparation ou de réfection des ponts, des installations de bacs et de passages d'eau, des digues, des écluses, des rades navigables, des ports de comm"}]}

# %% [markdown]
# ## 8. Local chunk retrieval inside the top hybrid documents
#
# Vue document par document, utile pour comprendre ce qui est disponible localement
# avant le rerank direct.

# %%
def local_chunk_hits(boi_reference, top_k=TOP_CHUNKS_PER_DOC):
    doc_chunks = chunks_by_ref.get(boi_reference, [])
    index = LexicalBM25Index(doc_chunks, search_text_fn=chunk_search_text_body)
    hits = index.search(QUERY, top_k=top_k)
    return [
        {
            "rank": hit.rank,
            "score": round(hit.score, 4),
            "chunk_id": hit.chunk.chunk_id,
            "chunk_kind": hit.chunk.chunk_kind,
            "token_count": hit.chunk.token_count,
            "section_path": " > ".join(hit.chunk.section_path),
            "paragraph_range": hit.chunk.paragraph_range,
            "text": hit.chunk.text[:800],
        }
        for hit in hits
    ]

local_results = {
    row["boi_reference"]: local_chunk_hits(row["boi_reference"])
    for row in hybrid_results_promoted[:3]
}
local_results
# Out:
# {'BOI-TVA-BASE-20-50-20-20-20120912': [{'rank': 1,
#    'score': 9.7801,
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00096__1472-pgp-paragraph-00097__iv-travaux-d-installation-d-quipements-fonctionnels-b-pr-cisions-compl-mentaires-2-installation-d-armoires-s-che-linge',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 135,
#    'section_path': "IV. Travaux d'installation d'équipements fonctionnels > B. Précisions complémentaires > 2. Installation d'armoires sèche-linge",
#    'paragraph_range': ['1472-PGP__paragraph__00096',
#     '1472-PGP__paragraph__00097'],
#    'text': "Le régime des travaux immobiliers s'applique aux installations d'armoires sèche-linge dans la mesure où elles font corps avec la maçonnerie de l'immeuble et perdent leur caractère mobilier par suite de leur incorporation aux locaux d'habitation. En revanche, lorsque les armoires sèche-linge se présentent sous la forme de meubles simplement raccordés au secteur électrique, à la distribution d'eau froide, à la colonne d'évacuation des eaux et que leur déplacement n'entraîne pas de graves détériorations soit des armoires elles-mêmes, soit de l'immeuble dans lequel elles ont disposées, de telles installations ne peuvent bénéficier du régime des travaux immobiliers, mais s'analysent en des ventes de matériels assorties de prestations de services."},
#   {'rank': 2,
#    'score': 9.6807,
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00000__1472-pgp-paragraph-00006__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers-cas-des-immeubles-affect-s-l-habitation-pour-les-trois-quarts-au-moins-de-leur-superficie',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 205,
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'paragraph_range': ['1472-PGP__paragraph__00000',
#     '1472-PGP__paragraph__00001',
#     '1472-PGP__paragraph__00002',
#     '1472-PGP__paragraph__00003',
#     '1472-PGP__paragraph__00004',
#     '1472-PGP__paragraph__00005',
#     '1472-PGP__paragraph__00006'],
#    'text': "En application des dispositions de l' article 78-3, al. 2 et 3 de l'annexe III au code général des impôts (CGI) , l'option ne s'applique pas aux travaux qui entrent dans le cadre des opérations concourant : - à la production ou à la livraison des immeubles dont les trois-quarts au moins de la superficie totale sont affectés à l'habitation ; - à la réparation et à la réfection des locaux d'habitation ainsi que de parties communes des immeubles dont les trois-quarts au moins de leur superficie sont affectés à l'habitation. Il sera tout d'abord procédé à la définition de la notion d'immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie pour ensuite préciser les travaux immobiliers concernés qui comprennent : - les travaux d'aménagement des terrains destinés à rec"},
#   {'rank': 3,
#    'score': 9.2811,
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00036__1472-pgp-paragraph-00036__i-d-finition-des-immeubles-affect-s-l-habitation-pour-les-trois-quarts-au-moins-de-leur-superficie-b-calcul-de-la-superficie-affect-e-l-habitation-4-garages',
#    'chunk_kind': 'paragraph',
#    'token_count': 126,
#    'section_path': "I. Définition des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie > B. Calcul de la superficie affectée à l'habitation > 4. Garages",
#    'paragraph_range': ['1472-PGP__paragraph__00036'],
#    'text': "Pour déterminer si un immeuble est destiné à être affecté à l'habitation pour les trois-quarts au moins de sa superficie totale, il convient de faire abstraction de la surface des garages autres que ceux constituant une exploitation commerciale. Toutefois, cette solution étant susceptible d'être défavorable aux redevables lorsque les garages constituent exclusivement ou principalement des dépendances de l'habitation, les parties ont la possibilité de demander qu'il soit tenu compte de leur surface et de leur destination, à la condition d'apporter la preuve de cette dernière, soit d'après les prescriptions du permis de construire, soit par tout autre moyen en leur pouvoir."},
#   {'rank': 4,
#    'score': 8.8767,
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00082__1472-pgp-paragraph-00084__iv-travaux-d-installation-d-quipements-fonctionnels-a-travaux-concern-s',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 141,
#    'section_path': "IV. Travaux d'installation d'équipements fonctionnels > A. Travaux concernés",
#    'paragraph_range': ['1472-PGP__paragraph__00082',
#     '1472-PGP__paragraph__00083',
#     '1472-PGP__paragraph__00084'],
#    'text': "Les travaux d'installation de ces équipements ne bénéficient pas de l'option, quelle que soit la nature du local où ils sont effectués dès lors qu'ils sont réalisés dans le cadre de la construction d'un immeuble affecté à l'habitation pour les trois-quarts au moins de sa superficie. La fourniture et la pose dans cet immeuble de tous les éléments autres que ceux visés au IV-A bénéficient de l'option. De même, sous réserve des dispositions analysées ci-dessus, les travaux immobiliers et les travaux d'installation de toute nature effectués dans le cadre de la construction des immeubles autres que ceux dont les trois-quarts au moins de la superficie sont affectés à l'habitation, ouvrent droit à l'option."}],
#  'BOI-TVA-BASE-20-50-20-30-20120912': [{'rank': 1,
#    'score': 9.5972,
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00044__1473-pgp-paragraph-00045__iii-pr-cisions-compl-mentaires-f-travaux-de-construction-d-un-centre-m-dico-p-dagogique-et-professionnel',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 120,
#    'section_path': "III. Précisions complémentaires > F. Travaux de construction d'un centre médico-pédagogique et professionnel",
#    'paragraph_range': ['1473-PGP__paragraph__00044',
#     '1473-PGP__paragraph__00045'],
#    'text': "Les travaux de construction d'un tel édifice n'ouvrent pas droit à l'option pour le paiement de la TVA lors de la livraison, à condition que cet immeuble soit affecté à l'habitation pour les trois quarts au moins de sa superficie. À cet égard, compte tenu de la nature de l'enseignement et des soins prodigués dans les centres médico-pédagogiques et professionnels, les locaux où séjournent les inadaptés mentaux placés sous le régime de l'externat sont considérés comme affectés à l'habitation, dès l'instant où les centres ne sont pas destinés à une exploitation de caractère industriel ou commercial."},
#   {'rank': 2,
#    'score': 7.855,
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00020__1473-pgp-paragraph-00027__iii-pr-cisions-compl-mentaires-b-travaux-d-tudes-et-de-reconnaissance-des-sols-1-nature-et-r-gime-des-op-rations-r-alis-es-dans-le-cadre-d-un-march-global-b-r-gime-fiscal-applicable',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 339,
#    'section_path': "III. Précisions complémentaires > B. Travaux d'études et de reconnaissance des sols > 1. Nature et régime des opérations réalisées dans le cadre d'un marché global > b. Régime fiscal applicable",
#    'paragraph_range': ['1473-PGP__paragraph__00020',
#     '1473-PGP__paragraph__00021',
#     '1473-PGP__paragraph__00022',
#     '1473-PGP__paragraph__00023',
#     '1473-PGP__paragraph__00024',
#     '1473-PGP__paragraph__00025',
#     '1473-PGP__paragraph__00026',
#     '1473-PGP__paragraph__00027'],
#    'text': "- travaux d'entreprise et travaux d'interprétation réalisés dans le cadre d'un marché global en vue de la recherche et de l'exploitation des eaux souterraines, des produits pétroliers et des substances minières ; L'ensemble des sondages, forages et des travaux d'interprétation préliminaires à l'exploitation de gisements, nappes, filons, sources, etc., s'analysent en des prestations de services. En revanche, bénéficient du régime des travaux immobiliers, les constructions, aménagements et travaux de nature immobilière entrepris en vue de déterminer l'importance des gisements ou nappes découverts, d'assurer l'extraction des minerais et autres produits, le captage des sources, le stockage du gaz dans les cavités souterraines, etc. - travaux d'entreprise et d'interprétation réalisés dans le ca"},
#   {'rank': 3,
#    'score': 7.4338,
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00013__1473-pgp-paragraph-00015__iii-pr-cisions-compl-mentaires-b-travaux-d-tudes-et-de-reconnaissance-des-sols__merge__iii-pr-cisions-compl-mentaires-b-travaux-d-tudes-et-de-reconnaissance-des-sols-1-nature-et-r-gime-des-op-rations-r-alis-es-dans-le-cadre-d-un-march-global-a-nature-des-op-rations',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 272,
#    'section_path': "III. Précisions complémentaires > B. Travaux d'études et de reconnaissance des sols",
#    'paragraph_range': ['1473-PGP__paragraph__00013',
#     '1473-PGP__paragraph__00014',
#     '1473-PGP__paragraph__00015',
#     '1473-PGP__paragraph__00016',
#     '1473-PGP__paragraph__00017',
#     '1473-PGP__paragraph__00018',
#     '1473-PGP__paragraph__00019'],
#    'text': "D'une manière générale, les travaux d'études et de reconnaissance de sols peuvent faire l'objet : - d'un marché global ; - ou de contrats distincts suivant la nature des prestations fournies.\n\nPar marché global d'études et de reconnaissance de sols, il faut entendre un marché portant à la fois sur des travaux d'interprétation (opérations de nature libérale consistant en études de caractère intellectuel et en analyses) et sur des travaux d'entreprise sur le terrain (travaux immobiliers et prestations de services de nature commerciale : sondages, forages, etc.) ayant, les uns et les autres, pour but : - soit la recherche et l'exploitation des eaux souterraines, des produits pétroliers, et des substances minières ; - soit les études et reconnaissances préalables aux travaux d'équipement et d'"},
#   {'rank': 4,
#    'score': 7.4255,
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00009__1473-pgp-paragraph-00009__ii-travaux-immobiliers-r-alis-s-par-les-redevables-inscrits-au-r-pertoire-des-m-tiers-plac-s-par-option-sous-le-r-gime-simplifi-d-imposition__merge__iii-pr-cisions-compl-mentaires-a-r-gime-d-imposition-des-d-penses-communes-de-chantier',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 239,
#    'section_path': "II. Travaux immobiliers réalisés par les redevables inscrits au répertoire des métiers placés par option sous le régime simplifié d'imposition",
#    'paragraph_range': ['1473-PGP__paragraph__00009',
#     '1473-PGP__paragraph__00010',
#     '1473-PGP__paragraph__00011',
#     '1473-PGP__paragraph__00012'],
#    'text': "Les opérations de simple entretien sont considérées comme des prestations de services.\n\nDans le cadre d'un marché de travaux immobiliers confié à plusieurs entreprises, le régime d'imposition à la TVA des dépenses communes de chantier dépend des modalités de règlement et de répartition de ces dépenses par l'entreprise qui expose en avance le montant pour le compte des entreprises participantes : - lorsque l'entreprise qui se voit confier la gestion de chantier n'a pas la qualité juridique de mandataire pour l'engagement et le règlement des dépenses communes (ce qui est notamment le cas lorsqu'elle répartit ces dépenses au prorata du montant des travaux réalisés par chacune des entreprises participantes) les remboursements effectués par ces entreprises constituent la rémunération de prestat"}],
#  'BOI-BIC-CHAMP-80-20-20-20-20240703': [{'rank': 1,
#    'score': 13.9685,
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00013__5357-pgp-paragraph-00014__i-nature-des-avantages-b-articulation-avec-le-b-n-fice-du-cr-dit-d-imp-t-pour-d-penses-de-recherche-cir-et-du-cr-dit-d-imp-t-en-faveur-de-la-recherche-collaborative-cico',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 180,
#    'section_path': "I. Nature des avantages > B. Articulation avec le bénéfice du crédit d'impôt pour dépenses de recherche (CIR) et du crédit d'impôt en faveur de la recherche collaborative (CICo)",
#    'paragraph_range': ['5357-PGP__paragraph__00013',
#     '5357-PGP__paragraph__00014'],
#    'text': "Le I de l' article 244 quater B du CGI et le I de l' article 244 quater B bis du CGI prévoient expressément que les entreprises exonérées d'impôt sur les bénéfices en application de l' article 44 sexies A du CGI peuvent également solliciter le bénéfice du CIR et du CICo. De plus, le 3° du II de l' article 199 ter B du CGI et le 3° du II de l' article 199 ter B bis du CGI prévoient la possibilité pour les JEI mentionnées à l' article 44 sexies-0 A du CGI de demander le remboursement immédiat du CIR et du CICo. Ainsi, les JEI, quelle que soit leur année de création, peuvent bénéficier du remboursement immédiat de leur créance de CIR ou de CICo constatée au titre d'une année au cours de laquelle elles bénéficient de la qualification de JEI."},
#   {'rank': 2,
#    'score': 10.5692,
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00078__5357-pgp-paragraph-00082__iii-combinaison-du-dispositif-avec-d-autres-r-gimes-d-exon-ration',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 330,
#    'section_path': "III. Combinaison du dispositif avec d'autres régimes d'exonération",
#    'paragraph_range': ['5357-PGP__paragraph__00078',
#     '5357-PGP__paragraph__00079',
#     '5357-PGP__paragraph__00080',
#     '5357-PGP__paragraph__00081',
#     '5357-PGP__paragraph__00082'],
#    'text': 'Il est précisé que les entreprises qui entendent bénéficier des exonérations d’impôts directs locaux attachées à ce statut de JEI, qu’il s’agisse de la taxe professionnelle (CGI, art. 1466 D), remplacée par la contribution économique territoriale à compter du 1 er janvier 2010, ou de la taxe foncière sur les propriétés bâties (CGI, art. 1383 D), doivent, dans la plupart des cas, en faire la demande sur papier libre. Concernant le second point, l’option est irrévocable. Toutefois, lorsqu’une entreprise répondant aux seules conditions d’éligibilité au statut de JEI a formulé auprès du service des impôts compétent, à tort, une option pour l’application d’un autre régime de faveur, elle peut demander le bénéfice du régime d’exonération prévu en faveur des JEI dans le cadre d’une réclamation co'},
#   {'rank': 3,
#    'score': 9.5998,
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00021__5357-pgp-paragraph-00028__ii-b-n-fices-susceptibles-d-tre-exon-r-s-c-produits-exclus-de-l-exon-ration',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 311,
#    'section_path': "II. Bénéfices susceptibles d'être exonérés > C. Produits exclus de l'exonération",
#    'paragraph_range': ['5357-PGP__paragraph__00021',
#     '5357-PGP__paragraph__00022',
#     '5357-PGP__paragraph__00023',
#     '5357-PGP__paragraph__00024',
#     '5357-PGP__paragraph__00025',
#     '5357-PGP__paragraph__00026',
#     '5357-PGP__paragraph__00027',
#     '5357-PGP__paragraph__00028'],
#    'text': "En application du II de l' article 44 sexies A du CGI , le régime d'exonération ne s'applique pas : aux produits des actions ou parts de société ; Remarque : Ces produits s'entendent des dividendes perçus de sociétés dans lesquelles la JEI détient des titres et des plus-values réalisées sur la cession de ces titres. Ces produits sont imposés selon le régime qui leur est propre. aux résultats de sociétés ou organismes soumis au régime prévu à l' article 8 du CGI ; Remarque : L'exonération ne s'applique pas à la quote-part de résultat qui revient à la JEI à raison des droits sociaux qu'elle détient dans une société ou un groupement relevant du régime fiscal des sociétés de personnes. Lorsque la quote-part de résultat est négative, celle-ci s'impute sur le bénéfice réalisé et susceptible d'êt"},
#   {'rank': 4,
#    'score': 9.3454,
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00075__5357-pgp-paragraph-00077__iii-combinaison-du-dispositif-avec-d-autres-r-gimes-d-exon-ration',
#    'chunk_kind': 'paragraph_window',
#    'token_count': 318,
#    'section_path': "III. Combinaison du dispositif avec d'autres régimes d'exonération",
#    'paragraph_range': ['5357-PGP__paragraph__00075',
#     '5357-PGP__paragraph__00076',
#     '5357-PGP__paragraph__00077'],
#    'text': "Au cas particulier, conformément au III de l’article 44 sexies A du CGI et au III § 200 à 230, 250 et 260 , lorsqu’une JEI réalisant des projets de recherche et de développement répond aux conditions requises pour bénéficier de l’un des régimes prévus à l'article 44 sexies du CGI, à l'article 44 septies du CGI, à l'article 44 octies du CGI, à l'article 44 decies du CGI, à l'article 244 quater E du CGI ou à l'article 44 sexies A du CGI en faveur des JEI et qu’elle décide d’opter pour le régime de faveur accordé aux JEI, elle doit notifier cette option au service des impôts dont elle relève dans les neuf mois suivant celui de son début d’activité ou dans les neuf premiers mois de l’exercice au titre duquel elle souhaite bénéficier des allègements prévus par l’article 44 sexies A du CGI. L’op"}]}

# %% [markdown]
# ## 9. Legacy lexical two-stage trace
#
# Reference utile pour comparaison historique. La baseline passage promue n'est plus ce retriever.

# %%
from bofip_cleanroom.two_stage_retrieval import TwoStageLexicalRetriever

retriever = TwoStageLexicalRetriever(
    raw_docs,
    chunks,
    document_mode="sections_leads",
    local_chunk_mode="body",
    local_strategy="chunk",
)
trace = retriever.search(QUERY, top_docs=TOP_DOCS, chunks_per_doc=3, max_chunks=8)

{
    "document_hits": [
        {
            "rank": hit.rank,
            "score": round(hit.score, 4),
            "boi_reference": hit.boi_reference,
            "title": raw_doc_map[hit.boi_reference].title,
        }
        for hit in trace.document_hits
    ],
    "chunk_hits": [
        {
            "global_rank": hit.global_rank,
            "document_rank": hit.document_rank,
            "local_rank": hit.local_rank,
            "local_score": round(hit.local_score, 4),
            "boi_reference": hit.boi_reference,
            "section_path": " > ".join(hit.chunk.section_path),
            "chunk_id": hit.chunk.chunk_id,
            "text": hit.chunk.text[:800],
        }
        for hit in trace.chunk_hits
    ],
}
# Out:
# {'document_hits': [{'rank': 1,
#    'score': 42.5416,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux"},
#   {'rank': 2,
#    'score': 40.1024,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Obligations déclaratives et contrôle'},
#   {'rank': 3,
#    'score': 39.8524,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie"},
#   {'rank': 4,
#    'score': 39.8261,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option"},
#   {'rank': 5,
#    'score': 39.627,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt en faveur de la recherche collaborative - Utilisation du crédit d’impôt'}],
#  'chunk_hits': [{'global_rank': 1,
#    'document_rank': 1,
#    'local_rank': 1,
#    'local_score': 10.5692,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'section_path': "III. Combinaison du dispositif avec d'autres régimes d'exonération",
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00078__5357-pgp-paragraph-00082__iii-combinaison-du-dispositif-avec-d-autres-r-gimes-d-exon-ration',
#    'text': 'Il est précisé que les entreprises qui entendent bénéficier des exonérations d’impôts directs locaux attachées à ce statut de JEI, qu’il s’agisse de la taxe professionnelle (CGI, art. 1466 D), remplacée par la contribution économique territoriale à compter du 1 er janvier 2010, ou de la taxe foncière sur les propriétés bâties (CGI, art. 1383 D), doivent, dans la plupart des cas, en faire la demande sur papier libre. Concernant le second point, l’option est irrévocable. Toutefois, lorsqu’une entreprise répondant aux seules conditions d’éligibilité au statut de JEI a formulé auprès du service des impôts compétent, à tort, une option pour l’application d’un autre régime de faveur, elle peut demander le bénéfice du régime d’exonération prévu en faveur des JEI dans le cadre d’une réclamation co'},
#   {'global_rank': 2,
#    'document_rank': 2,
#    'local_rank': 1,
#    'local_score': 12.0292,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'section_path': 'I. Souscription d’une déclaration spéciale conforme à un modèle établi par l’administration > B. Cas particuliers > 1. Pièces justificatives à produire par les entreprises créées depuis moins de deux ans > b. Pièces à produire',
#    'chunk_id': '4673-PGP__section_window__4673-pgp-paragraph-00027__4673-pgp-paragraph-00030__i-souscription-d-une-d-claration-sp-ciale-conforme-un-mod-le-tabli-par-l-administration-b-cas-particuliers-1-pi-ces-justificatives-produire-par-les-entreprises-cr-es-depuis-moins-de-deux-ans-b-pi-ces-produire',
#    'text': 'Les entreprises créées depuis moins de deux ans doivent présenter spontanément à l’appui de leur demande de remboursement immédiat de créance de CIR des pièces permettant d’établir la réalité de l’activité de recherche qu’elles exercent. Elles peuvent ainsi joindre, à leur demande de remboursement immédiat de créance de CIR, des documents tels que contrats, factures, déclaration DADS-U ou DSN et feuilles de paie délivrées aux chercheurs et techniciens ou tout autre moyen de preuve. Il n’est, toutefois, pas exigé que l’entreprise produise l’ensemble des justificatifs relatifs aux différentes catégories de dépenses éligibles au crédit d’impôt. En revanche, lors des demandes de restitution de crédit d’impôt ayant le caractère de réclamation contentieuse l’administration des finances publiques'},
#   {'global_rank': 3,
#    'document_rank': 3,
#    'local_rank': 1,
#    'local_score': 9.7801,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'section_path': "IV. Travaux d'installation d'équipements fonctionnels > B. Précisions complémentaires > 2. Installation d'armoires sèche-linge",
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00096__1472-pgp-paragraph-00097__iv-travaux-d-installation-d-quipements-fonctionnels-b-pr-cisions-compl-mentaires-2-installation-d-armoires-s-che-linge',
#    'text': "Le régime des travaux immobiliers s'applique aux installations d'armoires sèche-linge dans la mesure où elles font corps avec la maçonnerie de l'immeuble et perdent leur caractère mobilier par suite de leur incorporation aux locaux d'habitation. En revanche, lorsque les armoires sèche-linge se présentent sous la forme de meubles simplement raccordés au secteur électrique, à la distribution d'eau froide, à la colonne d'évacuation des eaux et que leur déplacement n'entraîne pas de graves détériorations soit des armoires elles-mêmes, soit de l'immeuble dans lequel elles ont disposées, de telles installations ne peuvent bénéficier du régime des travaux immobiliers, mais s'analysent en des ventes de matériels assorties de prestations de services."},
#   {'global_rank': 4,
#    'document_rank': 4,
#    'local_rank': 1,
#    'local_score': 9.5972,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-30-20120912',
#    'section_path': "III. Précisions complémentaires > F. Travaux de construction d'un centre médico-pédagogique et professionnel",
#    'chunk_id': '1473-PGP__section_window__1473-pgp-paragraph-00044__1473-pgp-paragraph-00045__iii-pr-cisions-compl-mentaires-f-travaux-de-construction-d-un-centre-m-dico-p-dagogique-et-professionnel',
#    'text': "Les travaux de construction d'un tel édifice n'ouvrent pas droit à l'option pour le paiement de la TVA lors de la livraison, à condition que cet immeuble soit affecté à l'habitation pour les trois quarts au moins de sa superficie. À cet égard, compte tenu de la nature de l'enseignement et des soins prodigués dans les centres médico-pédagogiques et professionnels, les locaux où séjournent les inadaptés mentaux placés sous le régime de l'externat sont considérés comme affectés à l'habitation, dès l'instant où les centres ne sont pas destinés à une exploitation de caractère industriel ou commercial."},
#   {'global_rank': 5,
#    'document_rank': 5,
#    'local_rank': 1,
#    'local_score': 6.9079,
#    'boi_reference': 'BOI-BIC-RICI-10-15-40-20250326',
#    'section_path': 'II. Nature, comptabilisation et utilisation de la créance de crédit d’impôt non imputé (solde excédentaire) > B. Utilisation de la créance > 1. Cas général',
#    'chunk_id': '13773-PGP__section_window__13773-pgp-paragraph-00016__13773-pgp-paragraph-00019__ii-nature-comptabilisation-et-utilisation-de-la-cr-ance-de-cr-dit-d-imp-t-non-imput-solde-exc-dentaire-b-utilisation-de-la-cr-ance-1-cas-g-n-ral',
#    'text': 'La créance est utilisée pour le paiement de l’impôt dû au titre des trois années suivant celle au titre de laquelle elle est constatée. Durant cette période, la créance est mobilisable auprès des établissements de crédit et des organismes de financement dans les cas et conditions prévus de l’ article L. 214-169 du CoMoFi à l’ article L. 214-190 du CoMoFi et de l’ article L. 313-23 du CoMoFi à l’ article L. 313-35 du CoMoFi , ou transférée dans le cadre des opérations de fusions (et assimilées) et du régime de groupe. Au terme de ce délai de trois ans, s’il y a lieu, la fraction non utilisée est remboursée. Dans ce cas, la créance n’est remboursée qu’à hauteur de la fraction qui n’a pas été utilisée. Les modalités d’utilisation de la créance étant identiques à celles applicables pour le cré'},
#   {'global_rank': 6,
#    'document_rank': 1,
#    'local_rank': 2,
#    'local_score': 13.9685,
#    'boi_reference': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#    'section_path': "I. Nature des avantages > B. Articulation avec le bénéfice du crédit d'impôt pour dépenses de recherche (CIR) et du crédit d'impôt en faveur de la recherche collaborative (CICo)",
#    'chunk_id': '5357-PGP__section_window__5357-pgp-paragraph-00013__5357-pgp-paragraph-00014__i-nature-des-avantages-b-articulation-avec-le-b-n-fice-du-cr-dit-d-imp-t-pour-d-penses-de-recherche-cir-et-du-cr-dit-d-imp-t-en-faveur-de-la-recherche-collaborative-cico',
#    'text': "Le I de l' article 244 quater B du CGI et le I de l' article 244 quater B bis du CGI prévoient expressément que les entreprises exonérées d'impôt sur les bénéfices en application de l' article 44 sexies A du CGI peuvent également solliciter le bénéfice du CIR et du CICo. De plus, le 3° du II de l' article 199 ter B du CGI et le 3° du II de l' article 199 ter B bis du CGI prévoient la possibilité pour les JEI mentionnées à l' article 44 sexies-0 A du CGI de demander le remboursement immédiat du CIR et du CICo. Ainsi, les JEI, quelle que soit leur année de création, peuvent bénéficier du remboursement immédiat de leur créance de CIR ou de CICo constatée au titre d'une année au cours de laquelle elles bénéficient de la qualification de JEI."},
#   {'global_rank': 7,
#    'document_rank': 2,
#    'local_rank': 2,
#    'local_score': 11.3695,
#    'boi_reference': 'BOI-BIC-RICI-10-10-60-20250813',
#    'section_path': 'II. Contrôle du crédit d’impôt recherche > A. Exercice du droit de contrôle',
#    'chunk_id': '4673-PGP__section_window__4673-pgp-paragraph-00060__4673-pgp-paragraph-00064__ii-contr-le-du-cr-dit-d-imp-t-recherche-a-exercice-du-droit-de-contr-le',
#    'text': 'Lorsque le ministère chargé de la recherche a effectué le contrôle prévu à l’article R. 45 B-1 du LPF, le simple renvoi à la notification des résultats de cette vérification ne pourra être regardé comme une motivation suffisante des rehaussements notifiés par l’administration fiscale. Les éléments communiqués par ledit ministère doivent donc figurer en clair dans le corps de la proposition de rectification. À la suite de la réception de la proposition de rectification, le contribuable peut formuler ses observations dans les conditions détaillées au II § 190 et suivants du BOI-CF-IOR-10-50-10 . Le contribuable dispose alors d’un délai de trente jours à compter de la réception de la réponse de l’administration à ses observations n° 3926-SD pour demander, sous peine d’irrecevabilité, la saisi'},
#   {'global_rank': 8,
#    'document_rank': 3,
#    'local_rank': 2,
#    'local_score': 9.6807,
#    'boi_reference': 'BOI-TVA-BASE-20-50-20-20-20120912',
#    'section_path': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Cas des immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie",
#    'chunk_id': '1472-PGP__section_window__1472-pgp-paragraph-00000__1472-pgp-paragraph-00006__tva-base-d-imposition-fait-g-n-rateur-et-exigibilit-modification-de-l-exigibilit-de-la-tva-la-suite-d-une-option-exclusion-de-l-option-pour-le-paiement-de-la-tva-sur-les-livraisons-de-travaux-immobiliers-cas-des-immeubles-affect-s-l-habitation-pour-les-trois-quarts-au-moins-de-leur-superficie',
#    'text': "En application des dispositions de l' article 78-3, al. 2 et 3 de l'annexe III au code général des impôts (CGI) , l'option ne s'applique pas aux travaux qui entrent dans le cadre des opérations concourant : - à la production ou à la livraison des immeubles dont les trois-quarts au moins de la superficie totale sont affectés à l'habitation ; - à la réparation et à la réfection des locaux d'habitation ainsi que de parties communes des immeubles dont les trois-quarts au moins de leur superficie sont affectés à l'habitation. Il sera tout d'abord procédé à la définition de la notion d'immeubles affectés à l'habitation pour les trois-quarts au moins de leur superficie pour ensuite préciser les travaux immobiliers concernés qui comprennent : - les travaux d'aménagement des terrains destinés à rec"}]}

# %% [markdown]
# ## 10. Reading guide
#
# Interprete le notebook comme suit:
# - si lexical, dense et hybride divergent fortement sur le top document, la requete est dure
# - si le bon document apparait dans `document_hits` mais que `direct_chunk_hits` ne contient pas le bon passage, le probleme est local au stage 2
# - si la famille BOI est bonne mais le sous-doc exact differe, on a une confusion parent/enfant ou voisin de famille
# - si rien de plausible ne remonte, c'est un vrai miss retrieval
