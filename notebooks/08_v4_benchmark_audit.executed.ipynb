# %% [markdown]
# # V4 Benchmark Audit
#
# Audit du benchmark `v4` sur `100` questions nouvelles:
# - `70` answerables
# - `30` unsupported
#
# Objectif:
# - mesurer l'effet d'un jeu de questions plus paraphrase et moins lexicalement confortable
# - comparer `Commentaire-only` et corpus `mixte`
# - comparer lexical, dense et hybride au niveau **documentaire**

# %%
from pathlib import Path
import json
import sys

PROJECT_ROOT = Path.cwd().resolve().parent
SRC_ROOT = PROJECT_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

def load_json(path):
    return json.loads(Path(path).read_text(encoding="utf-8"))

commentary_lex_base = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_5666__retrieval_queries_full_v4__base.json")
commentary_lex_sections = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_5666__retrieval_queries_full_v4__sections.json")
commentary_lex_sections_firstpara = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_5666__retrieval_queries_full_v4__sections_firstpara.json")
commentary_lex_sections_leads = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_5666__retrieval_queries_full_v4__sections_leads.json")
mixed_lex_base = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_6295__retrieval_queries_full_v4__base.json")
mixed_lex_sections = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_6295__retrieval_queries_full_v4__sections.json")
mixed_lex_sections_firstpara = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_lexical_eval_raw_docs_sample_6295__retrieval_queries_full_v4__sections_firstpara.json")

commentary_dense = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_dense_eval_raw_docs_sample_5666__retrieval_queries_full_v4__sections_firstpara__intfloat__multilingual-e5-base.json")
commentary_chunk_dense = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_dense_eval_chunks_section_window_sample_5666__full__intfloat__multilingual-e5-base.json")
mixed_dense = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_dense_eval_raw_docs_sample_6295__retrieval_queries_full_v4__sections_firstpara__intfloat__multilingual-e5-base.json")

commentary_hybrid = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_hybrid_eval_raw_docs_sample_5666__retrieval_queries_full_v4__docsections__densesections_firstpara__intfloat__multilingual-e5-base_lw1p0_dw1p0.json")
commentary_hybrid_best = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_multiview_hybrid_eval_raw_docs_sample_5666__retrieval_queries_full_v4__lexbase_sections_leads__densesections_firstpara__intfloat__multilingual-e5-base__base1p0_chunk_dense2p0_dense1p0_sections_leads2p0.json")
mixed_hybrid = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_doc_hybrid_eval_raw_docs_sample_6295__retrieval_queries_full_v4__docsections__densesections_firstpara__intfloat__multilingual-e5-base_lw1p0_dw1p0.json")

commentary_fail = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_failure_analysis_phase3_doc_multiview_hybrid_eval_raw_docs_sample_5666__retrieval_queries_full_v4__balanced_sections_leads.json")
mixed_fail = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_failure_analysis_phase3_doc_lexical_eval_raw_docs_sample_6295__retrieval_queries_full_v4__sections.json")

commentary_local = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_local_strategy_audit_retrieval_queries_full_v4__sections_body_5666.json")
mixed_local = load_json(PROJECT_ROOT / "data" / "reports" / "phase3_local_strategy_audit_retrieval_queries_full_v4__sections_body_6295.json")

# %% [markdown]
# ## 1. Headline metrics

# %%
{
    "commentary_lexical": {
        "base": commentary_lex_base["metrics"],
        "sections": commentary_lex_sections["metrics"],
        "sections_firstpara": commentary_lex_sections_firstpara["metrics"],
        "sections_leads": commentary_lex_sections_leads["metrics"],
    },
    "mixed_lexical": {
        "base": mixed_lex_base["metrics"],
        "sections": mixed_lex_sections["metrics"],
        "sections_firstpara": mixed_lex_sections_firstpara["metrics"],
    },
    "commentary_dense": commentary_dense["metrics"],
    "commentary_chunk_dense": commentary_chunk_dense["metrics"],
    "mixed_dense": mixed_dense["metrics"],
    "commentary_hybrid": commentary_hybrid["metrics"],
    "commentary_hybrid_best_current": commentary_hybrid_best["metrics"],
    "mixed_hybrid": mixed_hybrid["metrics"],
}
# Out:
# {'commentary_lexical': {'base': {'hit@1': 0.3286,
#    'hit@3': 0.5143,
#    'hit@5': 0.6143},
#   'sections': {'hit@1': 0.3714, 'hit@3': 0.5571, 'hit@5': 0.6571},
#   'sections_firstpara': {'hit@1': 0.3429, 'hit@3': 0.5571, 'hit@5': 0.6},
#   'sections_leads': {'hit@1': 0.4286, 'hit@3': 0.6857, 'hit@5': 0.7571}},
#  'mixed_lexical': {'base': {'hit@1': 0.3143, 'hit@3': 0.4857, 'hit@5': 0.5429},
#   'sections': {'hit@1': 0.3571, 'hit@3': 0.5571, 'hit@5': 0.6143},
#   'sections_firstpara': {'hit@1': 0.3571, 'hit@3': 0.5571, 'hit@5': 0.6}},
#  'commentary_dense': {'hit@1': 0.3, 'hit@3': 0.5857, 'hit@5': 0.7},
#  'commentary_chunk_dense': {'hit@1': 0.3714, 'hit@3': 0.5286, 'hit@5': 0.6286},
#  'mixed_dense': {'hit@1': 0.2857, 'hit@3': 0.5857, 'hit@5': 0.6714},
#  'commentary_hybrid': {'hit@1': 0.4286, 'hit@3': 0.6286, 'hit@5': 0.7429},
#  'commentary_hybrid_best_current': {'hit@1': 0.5286,
#   'hit@3': 0.7,
#   'hit@5': 0.7714},
#  'mixed_hybrid': {'hit@1': 0.4286, 'hit@3': 0.6286, 'hit@5': 0.7571}}

# %% [markdown]
# ## 2. Reading the result correctly
#
# Le benchmark `v4` casse le confort lexical:
# - les questions reprennent moins les formulations des titres BOI
# - elles ressemblent davantage a des demandes utilisateur
# - le benchmark precedent etait donc trop optimiste pour le stage 1 documentaire

# %%
{
    "commentary_miss_categories": commentary_fail["reports"][0]["miss_categories"],
    "mixed_miss_categories": mixed_fail["reports"][0]["miss_categories"],
    "commentary_miss_count": commentary_fail["reports"][0]["miss_count"],
    "mixed_miss_count": mixed_fail["reports"][0]["miss_count"],
}
# Out:
# {'commentary_miss_categories': {'same_domain_neighbor': 3,
#   'same_family_neighbor': 16,
#   'parent_child_family_confusion': 7,
#   'true_top1_miss': 4,
#   'title_equivalent_or_version_confusion': 3},
#  'mixed_miss_categories': {'true_top1_miss': 12,
#   'same_family_neighbor': 17,
#   'same_domain_neighbor': 6,
#   'title_equivalent_or_version_confusion': 4,
#   'parent_child_family_confusion': 6},
#  'commentary_miss_count': 33,
#  'mixed_miss_count': 45}

# %% [markdown]
# ## 3. Stage 2 local chunk selection under v4

# %%
{
    "commentary_local": commentary_local["summary"],
    "mixed_local": mixed_local["summary"],
}
# Out:
# {'commentary_local': {'chunk': {'query_count': 70,
#    'doc_hit1_rate': 0.3714,
#    'top_chunk_evaluated_count': 26,
#    'title_only_section_rate': 0.5,
#    'actualite_rate': 0.0,
#    'avg_token_count': 241.3,
#    'avg_overlap_count': 9.88,
#    'avg_overlap_ratio': 0.6259},
#   'section_then_chunk': {'query_count': 70,
#    'doc_hit1_rate': 0.3714,
#    'top_chunk_evaluated_count': 26,
#    'title_only_section_rate': 0.5385,
#    'actualite_rate': 0.0,
#    'avg_token_count': 232.2,
#    'avg_overlap_count': 9.46,
#    'avg_overlap_ratio': 0.6002}},
#  'mixed_local': {'chunk': {'query_count': 70,
#    'doc_hit1_rate': 0.3571,
#    'top_chunk_evaluated_count': 25,
#    'title_only_section_rate': 0.48,
#    'actualite_rate': 0.0,
#    'avg_token_count': 237.2,
#    'avg_overlap_count': 9.96,
#    'avg_overlap_ratio': 0.6296},
#   'section_then_chunk': {'query_count': 70,
#    'doc_hit1_rate': 0.3571,
#    'top_chunk_evaluated_count': 25,
#    'title_only_section_rate': 0.52,
#    'actualite_rate': 0.0,
#    'avg_token_count': 227.8,
#    'avg_overlap_count': 9.52,
#    'avg_overlap_ratio': 0.6029}}}

# %% [markdown]
# ## 4. Representative misses

# %%
commentary_fail["reports"][0]["misses"][:15]
# Out:
# [{'id': 'a001',
#   'pattern': 'scenario_business',
#   'query': 'Notre startup a le statut JEI et porte des travaux de recherche. Peut-elle recuperer sa creance de CIR tout de suite ?',
#   'expected_boi': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#   'expected_title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux",
#   'top1_boi': 'BOI-BIC-RICI-10-15-40-20250326',
#   'top1_title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt en faveur de la recherche collaborative - Utilisation du crédit d’impôt',
#   'top1_section': None,
#   'hit@3': True,
#   'category': 'same_domain_neighbor'},
#  {'id': 'a002',
#   'pattern': 'paraphrase',
#   'query': "Dans l'assiette du CIR, qu'est-ce qu'on peut ranger dans les frais de fonctionnement autour des travaux de recherche ?",
#   'expected_boi': 'BOI-BIC-RICI-10-10-20-25-20250813',
#   'expected_title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Dépenses de recherche éligibles - Autres dépenses de fonctionnement',
#   'top1_boi': 'BOI-BIC-RICI-10-10-30-10-20250813',
#   'top1_title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Détermination du crédit d’impôt - Taux applicables',
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'same_family_neighbor'},
#  {'id': 'a003',
#   'pattern': 'scenario_business',
#   'query': "Pour des avances remboursables sans interet destinees a des travaux energetiques, quel mecanisme de credit d'impot existe ?",
#   'expected_boi': 'BOI-BIC-RICI-10-110-20-20241127',
#   'expected_title': "BIC - Réductions et crédits d'impôt - Crédits d'impôt - Crédit d'impôt au titre des avances remboursables ne portant pas intérêt pour le financement de travaux d'amélioration de la performance énergétique des logements anciens - Modalités d'application",
#   'top1_boi': 'BOI-BIC-RICI-10-110-20241127',
#   'top1_title': "BIC - Réductions et crédits d'impôt - Crédits d'impôt - Crédit d'impôt au titre des avances remboursables ne portant pas intérêt pour le financement de travaux d'amélioration de la performance énergétique des logements anciens",
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'parent_child_family_confusion'},
#  {'id': 'a004',
#   'pattern': 'procedural_question',
#   'query': "Apres la mise en place du PAS, jusqu'a quand l'administration peut-elle encore rectifier les revenus 2018 ?",
#   'expected_boi': 'BOI-IR-PAS-50-20-50-20200210',
#   'expected_title': "IR - Prélèvement à la source de l'impôt sur le revenu - Mesures transitoires - Autres mesures transitoires - Extension du délai de reprise pour l'imposition des revenus de 2018",
#   'top1_boi': 'BOI-IR-PAS-50-20-40-20180704',
#   'top1_title': "IR - Prélèvement à la source de l'impôt sur le revenu - Mesures transitoires - Autres mesures transitoires - Procédure de rescrit relatif aux salaires éligibles au crédit d'impôt pour la modernisation du recouvrement",
#   'top1_section': None,
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a009',
#   'pattern': 'near_neighbor',
#   'query': "Dans l'integration fiscale, comment s'apprecie la sous-capitalisation au niveau du groupe ?",
#   'expected_boi': 'BOI-IS-GPE-20-20-70-20190731',
#   'expected_title': "IS - Régime fiscal des groupes de sociétés - Retraitements nécessaires à la détermination du résultat et de la plus ou moins-value d'ensemble - Traitement du mécanisme de la sous-capitalisation",
#   'top1_boi': 'BOI-IS-BASE-35-20-40-10-20190731',
#   'top1_title': "IS - Base d'imposition - Charges financières - Limitation des intérêts dans le cadre du dispositif de lutte contre la sous-capitalisation - Conséquences de la sous-capitalisation - Conséquences au sein d'un groupe non intégré",
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'same_domain_neighbor'},
#  {'id': 'a010',
#   'pattern': 'false_premise_answerable',
#   'query': 'Le BOFiP dit-il que toute publication de presse echappe automatiquement a la TVA ?',
#   'expected_boi': 'BOI-TVA-SECT-40-10-30-20130621',
#   'expected_title': "TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux publications de presse - Modalités d'imposition et de déclaration de la taxe portant sur les publications de presse",
#   'top1_boi': 'BOI-TVA-SECT-40-10-20-20240724',
#   'top1_title': 'TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux publications de presse - Opérations portant sur les publications de presse',
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'same_family_neighbor'},
#  {'id': 'a017',
#   'pattern': 'near_neighbor',
#   'query': "Pour les actes de la vie sociale, dans quels cas le regime special des fusions peut-il s'appliquer ?",
#   'expected_boi': 'BOI-ENR-AVS-20-60-30-10-20140613',
#   'expected_title': "ENR - Droits dus sur les actes relatifs à la vie des sociétés et assimilés - Champ d'application du régime spécial des fusions",
#   'top1_boi': 'BOI-ENR-AVS-20-60-30-20-20140210',
#   'top1_title': 'ENR - Droits dus sur les actes relatifs à la vie des sociétés et assimilés - Contenu du régime spécial des fusions',
#   'top1_section': None,
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a022',
#   'pattern': 'false_premise_answerable',
#   'query': 'Une entreprise peut-elle choisir librement de ne pas comptabiliser un amortissement pourtant obligatoire ?',
#   'expected_boi': 'BOI-BIC-AMT-10-50-10-20120912',
#   'expected_title': "BIC - Amortissements – Règles de déduction – Comptabilisation des amortissements – Obligation de constater l'amortissement en comptabilité",
#   'top1_boi': 'BOI-BIC-AMT-10-50-30-20170802',
#   'top1_title': 'BIC - Amortissements - Règles de déduction - Comptabilisation des amortissements - Obligation de constater un amortissement minimal',
#   'top1_section': None,
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a025',
#   'pattern': 'keyword_short',
#   'query': "A quoi ressemble le bareme de l'IFI aujourd'hui ?",
#   'expected_boi': 'BOI-PAT-IFI-40-10-20180608',
#   'expected_title': "PAT - IFI - Calcul de l'impôt - Tarif de l'impôt",
#   'top1_boi': 'BOI-PAT-IFI-20-10-20180608',
#   'top1_title': 'PAT - IFI - Assiette - Détermination des personnes imposables - Le redevable et son foyer fiscal',
#   'top1_section': None,
#   'hit@3': True,
#   'category': 'true_top1_miss'},
#  {'id': 'a026',
#   'pattern': 'topic_specific',
#   'query': "Une personne physique residente de France est-elle toujours dans le champ de l'IFI ?",
#   'expected_boi': 'BOI-PAT-IFI-10-20-20-20180608',
#   'expected_title': "PAT - IFI - Champ d'application - Personnes imposables - Personnes physiques domiciliées en France",
#   'top1_boi': 'BOI-INT-CVB-ITA-10-10-20120912',
#   'top1_title': "INT – Convention fiscale entre la France et l'Italie en matière d'impôts sur le revenu et sur la fortune - Champ d'application",
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'true_top1_miss'},
#  {'id': 'a027',
#   'pattern': 'false_premise_answerable',
#   'query': "Le plafonnement de l'IFI joue-t-il sans aucune condition ni limite particuliere ?",
#   'expected_boi': 'BOI-PAT-IFI-40-30-10-20181122',
#   'expected_title': "PAT - IFI - Calcul de l'impôt - Plafonnement - Modalités d'application du plafonnement",
#   'top1_boi': 'BOI-PAT-IFI-40-30-20-20190802',
#   'top1_title': "PAT - IFI - Calcul de l'impôt - Plafonnement - Clause anti-abus - Prise en compte des revenus distribués à certaines sociétés passibles de l’impôt sur les sociétés",
#   'top1_section': None,
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a028',
#   'pattern': 'topic_specific',
#   'query': 'Une plateforme en ligne de mise en relation a quelles obligations fiscales de base ?',
#   'expected_boi': 'BOI-INT-AEA-30-10-20230111',
#   'expected_title': "INT - Accords et échange automatique de renseignements - Obligations des opérateurs de plateforme de mise en relation par voie électronique - Champ d'application",
#   'top1_boi': 'BOI-BIC-DECLA-30-70-40-10-20210813',
#   'top1_title': "BIC - Régimes d'imposition et obligations déclaratives - Obligations déclaratives - Obligations déclaratives spécifiques ou communes - Obligations des opérateurs de plateforme de mise en relation par voie électronique - Champ d'application des obligations",
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'title_equivalent_or_version_confusion'},
#  {'id': 'a029',
#   'pattern': 'explicit_reference',
#   'query': 'Je cherche la doctrine generale sur les ETNC quand on raisonne en droit conventionnel.',
#   'expected_boi': 'BOI-INT-DG-20-50-20210224',
#   'expected_title': 'INT - Dispositions communes - Droit conventionnel - États et territoires non coopératifs',
#   'top1_boi': 'BOI-INT-DG-20-50-10-20210224',
#   'top1_title': 'INT - Dispositions communes - Droit conventionnel - États et territoires non coopératifs - Constitution et mise à jour de la liste des États et territoires non coopératifs',
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'parent_child_family_confusion'},
#  {'id': 'a030',
#   'pattern': 'topic_specific',
#   'query': 'Comment fonctionne le prelevement forfaitaire obligatoire sur les placements a revenu fixe ?',
#   'expected_boi': 'BOI-RPPM-RCM-30-20-40-20220630',
#   'expected_title': "RPPM - Revenus de capitaux mobiliers, gains et profits assimilés - Modalités particulières d'imposition - Prélèvement forfaitaire obligatoire non libératoire de l'impôt sur le revenu applicable aux produits de placement à revenu fixe, aux produits et gains de cession des bons ou contrats de capitalisation et placements de même nature attachés à des primes versées à compter du 27 septembre 2017, et aux revenus distribués - Taux applicables",
#   'top1_boi': 'BOI-RPPM-RCM-30-10-20-10-20191220',
#   'top1_title': "RPPM - Revenus de capitaux mobiliers, gains et profits assimilés - Modalités particulières d'imposition - Régime fiscal des produits de placements à revenu fixe et gains assimilés - Cas d'imposition à taux forfaitaire - Imposition sur option à un taux forfaitaire de 24 %",
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'same_family_neighbor'},
#  {'id': 'a031',
#   'pattern': 'keyword_short',
#   'query': 'Je veux un BOFiP qui regroupe les regles diverses restant a connaitre sur le PEA.',
#   'expected_boi': 'BOI-RPPM-RCM-40-50-60-20240730',
#   'expected_title': "RPPM - Revenus de capitaux mobiliers, gains et profits assimilés - Régimes particuliers - Plan d'épargne en actions - Dispositions diverses",
#   'top1_boi': 'BOI-BIC-PTP-20-30-20140915',
#   'top1_title': "BIC - Intéressement et participation - Régimes facultatifs - Plans d'épargne d'entreprise",
#   'top1_section': None,
#   'hit@3': False,
#   'category': 'true_top1_miss'}]

# %%
mixed_fail["reports"][0]["misses"][:15]
# Out:
# [{'id': 'a001',
#   'pattern': 'scenario_business',
#   'query': 'Notre startup a le statut JEI et porte des travaux de recherche. Peut-elle recuperer sa creance de CIR tout de suite ?',
#   'expected_boi': 'BOI-BIC-CHAMP-80-20-20-20-20240703',
#   'expected_title': "BIC - Champ d'application et territorialité - Exonérations - Entreprises exerçant une activité particulière - Jeunes entreprises innovantes, jeunes entreprises universitaires et jeunes entreprises de croissance - Portée et calcul des allègements fiscaux",
#   'top1_boi': 'BOI-TVA-BASE-20-50-20-30-20120912',
#   'top1_title': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#   'top1_section': "TVA - Base d'imposition - Fait générateur et exigibilité - Modification de l'exigibilité de la TVA à la suite d'une option - Exclusion de l'option pour le paiement de la TVA sur les livraisons de travaux immobiliers - Autres cas d'exclusion de l'option",
#   'hit@3': False,
#   'category': 'true_top1_miss'},
#  {'id': 'a002',
#   'pattern': 'paraphrase',
#   'query': "Dans l'assiette du CIR, qu'est-ce qu'on peut ranger dans les frais de fonctionnement autour des travaux de recherche ?",
#   'expected_boi': 'BOI-BIC-RICI-10-10-20-25-20250813',
#   'expected_title': 'BIC - Réductions et crédits d’impôt - Crédits d’impôt - Crédit d’impôt recherche - Dépenses de recherche éligibles - Autres dépenses de fonctionnement',
#   'top1_boi': 'BOI-BIC-CHG-80-10-20120912',
#   'top1_title': 'BIC - Frais et charges - Versements effectués dans les pays dont le régime fiscal est privilégié - Opérations pouvant entraîner la non déductibilité fiscale des versements',
#   'top1_section': 'BIC - Frais et charges - Versements effectués dans les pays dont le régime fiscal est privilégié - Opérations pouvant entraîner la non déductibilité fiscale des versements',
#   'hit@3': False,
#   'category': 'true_top1_miss'},
#  {'id': 'a003',
#   'pattern': 'scenario_business',
#   'query': "Pour des avances remboursables sans interet destinees a des travaux energetiques, quel mecanisme de credit d'impot existe ?",
#   'expected_boi': 'BOI-BIC-RICI-10-110-20-20241127',
#   'expected_title': "BIC - Réductions et crédits d'impôt - Crédits d'impôt - Crédit d'impôt au titre des avances remboursables ne portant pas intérêt pour le financement de travaux d'amélioration de la performance énergétique des logements anciens - Modalités d'application",
#   'top1_boi': 'BOI-BIC-RICI-10-110-10-20241127',
#   'top1_title': "BIC - Réductions et crédits d'impôt - Crédits d'impôt - Crédit d'impôt au titre des avances remboursables ne portant pas intérêt pour le financement de travaux d'amélioration de la performance énergétique des logements anciens - Champ d'application",
#   'top1_section': "BIC - Réductions et crédits d'impôt - Crédits d'impôt - Crédit d'impôt au titre des avances remboursables ne portant pas intérêt pour le financement de travaux d'amélioration de la performance énergétique des logements anciens - Champ d'application",
#   'hit@3': False,
#   'category': 'same_family_neighbor'},
#  {'id': 'a005',
#   'pattern': 'keyword_short',
#   'query': 'Quels encaissements ou revenus supportent un acompte de prelevement a la source ?',
#   'expected_boi': 'BOI-IR-PAS-10-10-20-20230706',
#   'expected_title': "IR - Prélèvement à la source de l'impôt sur le revenu - Champ d'application - Revenus dans le champ du prélèvement - Revenus soumis à l'acompte",
#   'top1_boi': 'BOI-IR-PAS-20-30-30-20180515',
#   'top1_title': "IR - Prélèvement à la source de l'impôt sur le revenu - Calcul du prélèvement - Actualisation du prélèvement - Début et fin de perception de revenus soumis à acompte",
#   'top1_section': "IR - Prélèvement à la source de l'impôt sur le revenu - Calcul du prélèvement - Actualisation du prélèvement - Début et fin de perception de revenus soumis à acompte",
#   'hit@3': False,
#   'category': 'same_domain_neighbor'},
#  {'id': 'a007',
#   'pattern': 'explicit_country',
#   'query': 'Ou trouver les regles France Algerie pour neutraliser la double imposition ?',
#   'expected_boi': 'BOI-INT-CVB-DZA-60-20141226',
#   'expected_title': "INT - Convention fiscale entre la France et l'Algérie - Élimination des doubles impositions",
#   'top1_boi': 'BOI-INT-CVB-DZA-20-20120912',
#   'top1_title': "INT - Convention fiscale entre la France et l'Algérie – Règles d'imposition des revenus immobiliers, des bénéfices agricoles et des bénéfices des entreprises",
#   'top1_section': "INT - Convention fiscale entre la France et l'Algérie – Règles d'imposition des revenus immobiliers, des bénéfices agricoles et des bénéfices des entreprises",
#   'hit@3': False,
#   'category': 'same_family_neighbor'},
#  {'id': 'a008',
#   'pattern': 'near_neighbor',
#   'query': 'Dans un groupe integre, que deviennent les deficits du groupe initial quand la mere est absorbee ?',
#   'expected_boi': 'BOI-IS-GPE-50-10-30-20210811',
#   'expected_title': "IS - Régime fiscal des groupes de sociétés - Opérations de restructurations du groupe - Absorption de la société mère, de l'entité mère non résidente ou d'une société étrangère - Sort des déficits, charges financières nettes non déduites et capacité de déduction inemployée de l'ancien groupe",
#   'top1_boi': 'BOI-FORM-000067-20210811',
#   'top1_title': "FORMULAIRE - IS - Etat de détermination des déficits subis par les sociétés filiales de l'ancien groupe, et par celles absorbées ou scindées au profit de ces dernières, pour lesquels la société a demandé une imputation élargie (y compris le cas échéant par la société mère absorbée)",
#   'top1_section': "FORMULAIRE - IS - Etat de détermination des déficits subis par les sociétés filiales de l'ancien groupe, et par celles absorbées ou scindées au profit de ces dernières, pour lesquels la société a demandé une imputation élargie (y compris le cas échéant par la société mère absorbée)",
#   'hit@3': False,
#   'category': 'title_equivalent_or_version_confusion'},
#  {'id': 'a009',
#   'pattern': 'near_neighbor',
#   'query': "Dans l'integration fiscale, comment s'apprecie la sous-capitalisation au niveau du groupe ?",
#   'expected_boi': 'BOI-IS-GPE-20-20-70-20190731',
#   'expected_title': "IS - Régime fiscal des groupes de sociétés - Retraitements nécessaires à la détermination du résultat et de la plus ou moins-value d'ensemble - Traitement du mécanisme de la sous-capitalisation",
#   'top1_boi': 'BOI-IS-BASE-35-20-40-20-20190731',
#   'top1_title': "IS - Base d'imposition - Charges financières - Limitation des intérêts dans le cadre du dispositif de lutte contre la sous-capitalisation - Conséquences de la sous-capitalisation - Conséquences au sein d'un groupe intégré",
#   'top1_section': "IS - Base d'imposition - Charges financières - Limitation des intérêts dans le cadre du dispositif de lutte contre la sous-capitalisation - Conséquences de la sous-capitalisation - Conséquences au sein d'un groupe intégré",
#   'hit@3': False,
#   'category': 'same_domain_neighbor'},
#  {'id': 'a010',
#   'pattern': 'false_premise_answerable',
#   'query': 'Le BOFiP dit-il que toute publication de presse echappe automatiquement a la TVA ?',
#   'expected_boi': 'BOI-TVA-SECT-40-10-30-20130621',
#   'expected_title': "TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux publications de presse - Modalités d'imposition et de déclaration de la taxe portant sur les publications de presse",
#   'top1_boi': 'BOI-TVA-SECT-40-10-10-20120912',
#   'top1_title': 'TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux publications de presse - Définitions des publications de presse',
#   'top1_section': 'TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux publications de presse - Définitions des publications de presse',
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a012',
#   'pattern': 'paraphrase',
#   'query': 'Qui doit reverser la TVA quand on parle de vente de biens ou de prestation de services en regime normal ?',
#   'expected_boi': 'BOI-TVA-DECLA-10-10-20-20251022',
#   'expected_title': 'TVA - Régimes d’imposition et obligations déclaratives et comptables - Redevable de la taxe - Livraisons de biens et prestations de services - Détermination du redevable',
#   'top1_boi': 'BOI-TVA-SECT-40-40-20181205',
#   'top1_title': 'TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux services de presse en ligne',
#   'top1_section': 'TVA - Régimes sectoriels - Régime de la presse - Régime applicable aux services de presse en ligne',
#   'hit@3': False,
#   'category': 'same_domain_neighbor'},
#  {'id': 'a016',
#   'pattern': 'topic_specific',
#   'query': 'Quel traitement fiscal pour une transformation de societe ou une simple retouche des statuts ?',
#   'expected_boi': 'BOI-ENR-AVS-20-30-30-20120912',
#   'expected_title': 'ENR - Droits dus sur les actes relatifs à la vie des sociétés et assimilés - Régime fiscal applicable aux transformations de sociétés et autres modifications statutaires assimilables',
#   'top1_boi': 'BOI-IS-BASE-30-40-20-20160504',
#   'top1_title': "IS - Base d'imposition - Charges - Bonis ristournés aux sociétaires d'organismes coopératifs, mutualistes et similaires - Sociétés coopératives de production (SCOP)",
#   'top1_section': "IS - Base d'imposition - Charges - Bonis ristournés aux sociétaires d'organismes coopératifs, mutualistes et similaires - Sociétés coopératives de production (SCOP)",
#   'hit@3': False,
#   'category': 'true_top1_miss'},
#  {'id': 'a017',
#   'pattern': 'near_neighbor',
#   'query': "Pour les actes de la vie sociale, dans quels cas le regime special des fusions peut-il s'appliquer ?",
#   'expected_boi': 'BOI-ENR-AVS-20-60-30-10-20140613',
#   'expected_title': "ENR - Droits dus sur les actes relatifs à la vie des sociétés et assimilés - Champ d'application du régime spécial des fusions",
#   'top1_boi': 'BOI-ENR-AVS-20-60-30-20-20140210',
#   'top1_title': 'ENR - Droits dus sur les actes relatifs à la vie des sociétés et assimilés - Contenu du régime spécial des fusions',
#   'top1_section': 'ENR - Droits dus sur les actes relatifs à la vie des sociétés et assimilés - Contenu du régime spécial des fusions',
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a019',
#   'pattern': 'paraphrase',
#   'query': 'Quand une commune change de contour ou fusionne, comment adapte-t-on les valeurs locatives ?',
#   'expected_boi': 'BOI-IF-TFB-20-20-10-40-20121210',
#   'expected_title': "IF - Taxes foncières sur les propriétés bâties et non bâties - Base d'imposition - Mise à jour des valeurs locatives - Changements de limites territoriales de communes",
#   'top1_boi': 'BOI-IF-TFB-20-10-20-70-20121210',
#   'top1_title': "IF - Taxe foncière sur les propriétés bâties – Base d'imposition – Détermination de la valeur locative cadastrale 1970 – Locaux d'habitation ou à usage professionnel ordinaires - Calcul des valeurs locatives individuelles",
#   'top1_section': "IF - Taxe foncière sur les propriétés bâties – Base d'imposition – Détermination de la valeur locative cadastrale 1970 – Locaux d'habitation ou à usage professionnel ordinaires - Calcul des valeurs locatives individuelles",
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a020',
#   'pattern': 'topic_specific',
#   'query': 'Pour la CVAE, comment calcule-t-on la valeur ajoutee de base sans entrer dans les cas particuliers ?',
#   'expected_boi': 'BOI-CVAE-BASE-10-20120912',
#   'expected_title': "CVAE – Modalités d'imposition – Règles générales de détermination de la valeur ajoutée",
#   'top1_boi': 'BOI-CVAE-BASE-20-20-20251119',
#   'top1_title': 'CVAE - Base d’imposition - Régime de droit commun - Calcul de la valeur ajoutée et plafonnement',
#   'top1_section': 'CVAE - Base d’imposition - Régime de droit commun - Calcul de la valeur ajoutée et plafonnement',
#   'hit@3': True,
#   'category': 'same_domain_neighbor'},
#  {'id': 'a022',
#   'pattern': 'false_premise_answerable',
#   'query': 'Une entreprise peut-elle choisir librement de ne pas comptabiliser un amortissement pourtant obligatoire ?',
#   'expected_boi': 'BOI-BIC-AMT-10-50-10-20120912',
#   'expected_title': "BIC - Amortissements – Règles de déduction – Comptabilisation des amortissements – Obligation de constater l'amortissement en comptabilité",
#   'top1_boi': 'BOI-BIC-AMT-10-30-40-20210609',
#   'top1_title': "BIC - Amortissements - Règles de déduction - Base de l'amortissement - Biens ayant fait l'objet d'une réévaluation",
#   'top1_section': "BIC - Amortissements - Règles de déduction - Base de l'amortissement - Biens ayant fait l'objet d'une réévaluation",
#   'hit@3': True,
#   'category': 'same_family_neighbor'},
#  {'id': 'a025',
#   'pattern': 'keyword_short',
#   'query': "A quoi ressemble le bareme de l'IFI aujourd'hui ?",
#   'expected_boi': 'BOI-PAT-IFI-40-10-20180608',
#   'expected_title': "PAT - IFI - Calcul de l'impôt - Tarif de l'impôt",
#   'top1_boi': 'BOI-BAREME-000001-20230720',
#   'top1_title': "BAREME - RSA - BNC - Barèmes d'évaluation forfaitaire du prix de revient kilométrique applicables aux automobiles et aux deux-roues motorisés",
#   'top1_section': "BAREME - RSA - BNC - Barèmes d'évaluation forfaitaire du prix de revient kilométrique applicables aux automobiles et aux deux-roues motorisés",
#   'hit@3': False,
#   'category': 'true_top1_miss'}]

# %% [markdown]
# ## 5. Conclusion
#
# Ce notebook dit maintenant quelque chose de plus fin:
# - le parsing/chunking restent stables
# - le benchmark `v4` est beaucoup plus exigeant
# - le meilleur baseline actuel combine `base + sections_leads + doc_dense + chunk_dense`
# - on a un vrai gain sur le retrieval documentaire, mais pas encore un niveau satisfaisant pour brancher sereinement un LLM
